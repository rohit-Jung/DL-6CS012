# %% [markdown]
# ## import libs
#
# - Import all libraries used across data loading, preprocessing, modeling, and evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## read the data
#
# - Load the CSV into a DataFrame and inspect the first few rows.
# - Confirm expected columns: `label` and `text`.

# %%
df = pd.read_csv("./dataset/hatevsoffensive_language.csv")
df.head(5)
# Out:
#                 label                                               text
# 0             neither  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  offensive language  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  offensive language  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  offensive language  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  offensive language  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
# Create output directories for figures
import os
for d in [
    './outputs/figures/eda',
    './outputs/figures/comparisons',
    './outputs/figures/training_curves',
    './outputs/figures/confusion_matrices',
]:
    os.makedirs(d, exist_ok=True)
    print(f'Created {d}')
# Out:
# Created ./outputs/figures/eda
# Created ./outputs/figures/comparisons
# Created ./outputs/figures/training_curves
# Created ./outputs/figures/confusion_matrices

# %%
df_text = df[['text']]
df_text.head(5)
# Out:
#                                                 text
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %% [markdown]
# ## text Preprocessing
#
# - Define helper functions to clean tweet-style text (URLs, emojis, punctuation, etc.).
# - Combine them into a single cleaning pipeline and apply it to the full dataset.
# - Verify the cleaned output is a string (not a token list) before tokenization.
# - Goal: reduce noise while keeping enough signal for sequence models (RNN/LSTM).

# %%
# preprocess the text
import re

# remove urls
def remove_urls(text): 
    """
    This function will try to remove URL present in out dataset and replace it with space using regex library.

    Input Args:
        text: strings of text that may contain URLs.

    Output Args:
        text: URLs replaces with text
    """
    url_pattern = re.compile(r'http[s]?: //\S+|www\.\S+')
    return url_pattern.sub(r'', text)

def remove_emoji(string): 
  """
  This function will replace the emoji in string with whitespace
  """
  emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251""]+", flags=re.UNICODE)
  return emoji_pattern.sub(r' ', string)

def removeunwanted_characters(document): 
    """Remove mentions/hashtags/punctuation and normalize whitespace.

    Notes:
        - Removes @mentions and #hashtags.
        - Replaces non-alphanumeric characters with spaces.
        - Removes emojis via `remove_emoji()`.

    Args:
        document (str): Raw text.

    Returns:
        str: Cleaned text.
    """
    document = re.sub('@[A-Za-z0-9_]+'," ", document) #mentions
    document = re.sub('#[A-Za-z0-9_]+', " ", document) #hashtags 
    document = re.sub('[^A-Za-z0-9 ]+', " ", document)  #punctuations
    document = remove_emoji(document)     # emojis
    document = document.replace(" ", " ") # double spaces
    return document.strip()

text_removed_unwanted = df['text'].apply(removeunwanted_characters)
text_removed_unwanted.head(4)
# Out:
# 0    RT    As a woman you shouldn t complain about ...
# 1    RT    boy dats cold tyga dwn bad for cuffin da...
# 2    RT   Dawg  RT    You ever fuck a bitch and she...
# 3                       RT      she look like a tranny
# Name: text, dtype: str

# %% [markdown]
# ### Helper functions: `remove_punct` and tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk import word_tokenize

from nltk.tokenize import RegexpTokenizer

def remove_punct(text): 
    """
     This function removes the punctutations present in our text data.

     Input Args:
         text: text data.

     Returns:
         text: cleaned text.
    """
    tokenizer = RegexpTokenizer(r"\w+")
    lst = tokenizer.tokenize(" ".join(text))
    return lst

remove_punct("He did not try to navigate: after the!!!! first bold flight, for,,,,, the reaction!!!!had taken??????? something out of his soul.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['H',
#  'e',
#  'd',
#  'i',
#  'd',
#  'n',
#  'o',
#  't',
#  't',
#  'r',
#  'y',
#  't',
#  'o',
#  'n',
#  'a',
#  'v',
#  'i',
#  'g',
#  'a',
#  't',
#  'e',
#  'a',
#  'f',
#  't',
#  'e',
#  'r',
#  't',
#  'h',
#  'e',
#  'f',
#  'i',
#  'r',
#  's',
#  't',
#  'b',
#  'o',
#  'l',
#  'd',
#  'f',
#  'l',
#  'i',
#  'g',
#  'h',
#  't',
#  'f',
#  'o',
#  'r',
#  't',
#  'h',
#  'e',
#  'r',
#  'e',
#  'a',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  'h',
#  'a',
#  'd',
#  't',
#  'a',
#  'k',
#  'e',
#  'n',
#  's',
#  'o',
#  'm',
#  'e',
#  't',
#  'h',
#  'i',
#  'n',
#  'g',
#  'o',
#  'u',
#  't',
#  'o',
#  'f',
#  'h',
#  'i',
#  's',
#  's',
#  'o',
#  'u',
#  'l']

# %% [markdown]
# ### remove stopwords

# %%
nltk.download("stopwords")
from  nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# get the stopwords
stop_words = set(stopwords.words("english"))

# add custom stopwords
custom_stopwords = ['@', 'RT', 'u', 'i', 'co']
stop_words.update(custom_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text_tokens): 
    """
     This function removes all the stopwords present in out text tokens.
     
     Input Args:
         text_tokens: tokenize input of our datasets.
     Returns:
         result_tokens: list of token without stopword.
    """
    result_tokens = []
    for token in text_tokens:
        if token not in stop_words:
            result_tokens.append(token)
    return result_tokens

remove_stopwords(['He', 'did', 'not', 'try', 'to', 'navigate', 'after', 'the', 'first', 'bold', 'flight', ',', 'for', 'the', 'reaction', 'had', 'taken', 'something', 'out', 'of', 'his', 'soul', '.'
])
# Out:
# ['He',
#  'try',
#  'navigate',
#  'first',
#  'bold',
#  'flight',
#  ',',
#  'reaction',
#  'taken',
#  'something',
#  'soul',
#  '.']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

def lemmatization(token_text): 
    """
    This function performs the lemmatization operations as explained above.

    Input Args:
        token_text: list of tokens.

    Returns:
        lemmatized_tokens: list of lemmatized tokens.
    """
    wordnet = WordNetLemmatizer()
    lemmatized_tokens = [wordnet.lemmatize(token.lower(), pos = 'v') for token in token_text]
    return lemmatized_tokens

lemmatization("Should we go walking or swimming".split())
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['should', 'we', 'go', 'walk', 'or', 'swim']

# %%
from nltk.stem import PorterStemmer

def stemming(text): 
  """
    This function performs stemming operations.

    Input Args:
        token_text: list of tokenize text.

    Returns:
        stemm_tokes: list of stemmed tokens.
    """
  porter = PorterStemmer()
  stemm_tokens = [porter.stem(token) for token in text]
  return stemm_tokens

# test
stemming(['Connects','Connecting','Connections','Connected','Connection','Connectings','Connect' ])
# Out:
# ['connect', 'connect', 'connect', 'connect', 'connect', 'connect', 'connect']

# %%
def lower_order(text): 
    """
    This function converts all the text in input text to lower order.

    Input Args:
        token_text : input text.

    Returns:
        small_order_text : text converted to small/lower order.
    """
    return  text.lower()

lower_order("This Is some Normalized TEXT")
# Out:
# 'this is some normalized text'

# %%
def remove_contradictions(text): 
    """
    This function replaces the contractions in text with their expanded form.

    Input Args:
        text: input text.

    Returns:
        expanded_text: text with contractions replaced by their expanded form.
    """
    contractions_dict = {
    "can't": "cannot",
    "won't": "will not",
    "n't": " not",
    "'re": " are",
    "'s": " is",
    "'d": " would",
    "'ll": " will",
    "'t": " not",
    "'ve": " have",
    "'m": " am",
    "aint": "am not",
    "arent": "are not",
    "cant": "cannot",
    }

    contractions_re = re.compile('(%s)' % '|'.join(contractions_dict.keys()))

    def expand_contractions(s, contractions_dict=contractions_dict):
        def replace(match):
            return contractions_dict[match.group(0) ]
        return contractions_re.sub(replace, s)

    expanded_text = expand_contractions(text)
    return expanded_text
  
remove_contradictions("I can't go to the party because I won't have time.")
# Out:
# 'I cannot go to the party because I will not have time.'

# %%
def text_cleaning_pipeline(dataset, rule = "lemmatize"): 
  """
  This function cleans up the text, changes order, remove url, emojis and unwanted characters
  turns them to token and then lemmatize or stemm them according to the rule passed

  Input Args:
    dataset: the data col to perform these operations on
    rule: Whether to lemmatize or stemm it (Default is lemmatize)

  Output:
    cleaned list of tokens
  """
  # Remove URLs
  data = remove_urls(dataset)

  # Remove emojis
  data = remove_emoji(dataset)

  # Remove contractions
  data = remove_contradictions(dataset)

  # Remove all other unwanted characters.
  data = removeunwanted_characters(dataset)

  # Convert the input to small/lower order.
  data = lower_order(dataset)

  # Create tokens.
  tokens = data.split()

  # Remove stopwords
  tokens = remove_stopwords(tokens)

  # Remove punctuations
  tokens = remove_punct(tokens)

  if rule == "lemmatize":
    tokens = lemmatization(tokens)
  elif rule == "stem":
    tokens = stemming(tokens)
  else:
    print("Pick between lemmatize or stem")

  return " ".join(tokens)

# test
text_cleaning_pipeline( "Hello @gabe_flomo 👋🏾, I still want us to hit that new sushi spot??? LMK when you're free cuz I can't go this or next weekend since I'll be swimming!!! #sushiBros #rawFish #🍱")
# Out:
# 'hello gabe_flomo still want us hit new sushi spot lmk free cuz can t go next weekend since swim sushibros rawfish'

# %%
# apply on real data
df["cleaned"] = df['text'].apply(lambda data: text_cleaning_pipeline(data))
df["cleaned"].head(4)
# Out:
# 0    rt mayasolovely woman complain clean house amp...
# 1    rt mleew17 boy dats cold tyga dwn bad cuffin d...
# 2    rt urkindofbrand dawg rt 80sbaby4life ever fuc...
# 3          rt c_g_anderson viva_based look like tranny
# Name: cleaned, dtype: str

# %%
print(df.columns)
print(type(df["cleaned" ].iloc[0]))  # should be str, not list
# Out:
# Index(['label', 'text', 'cleaned'], dtype='str')
# <class 'str'>

# %% [markdown]
# ## Visualization
#
# - Explore the cleaned corpus to understand common terms and overall noise.
# - Generate a word frequency list and a word cloud.

# %%
from collections import Counter

all_words = " ".join(df['cleaned']).split()

common_words = Counter(all_words).most_common(20)
print(common_words)
# Out:
# [('bitch', 11481), ('rt', 7647), ('t', 4689), ('hoe', 4359), ('128514', 3241), ('get', 3081), ('co', 3005), ('http', 2915), ('like', 2862), ('fuck', 2267), ('pussy', 2160), ('8220', 1726), ('8221', 1682), ('s', 1651), ('ass', 1579), ('shit', 1312), ('go', 1278), ('8230', 1265), ('nigga', 1229), ('trash', 1167)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Generate word cloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white'
).generate(df['cleaned'].str.cat(sep=' '))

# Display
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('./outputs/figures/eda/wordcloud.png', bbox_inches='tight', dpi=150)
plt.show()

# %%
# EDA: Text length distribution
text_lengths = df['cleaned'].str.split().str.len()
plt.figure(figsize=(8, 5))
plt.hist(text_lengths, bins=30, color='steelblue', edgecolor='black', alpha=0.7)

plt.axvline(x=np.percentile(text_lengths, 95), color='red', linestyle='--', label=f'95th percentile = {np.percentile(text_lengths,95):.0f}')

plt.axvline(x=text_lengths.median(), color='green', linestyle=':', label=f'Median = {text_lengths.median():.1f}')

plt.title('Distribution of Tweet Lengths (after cleaning)', fontsize=14, fontweight='bold')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
os.makedirs('./outputs/figures/eda', exist_ok=True)
plt.savefig('./outputs/figures/eda/text_length_distribution.png', bbox_inches='tight', dpi=150)
plt.show()
print(f'Max length: {text_lengths.max()}')
print(f'95th percentile: {np.percentile(text_lengths, 95):.0f}')
print(f'Median: {text_lengths.median():.0f}')
# Out:
# Max length: 85
# 95th percentile: 19
# Median: 10

# %% [markdown]
# ## Train test split
#
# - Split the cleaned text and labels into train/test sets (80/20).
# - Fix the random seed for reproducibility.
# - We split before tokenization to avoid information leakage from the test set vocabulary.

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['cleaned'],
                                                    df['label'],
                                                    test_size=0.2,
                                                    random_state=42)

print(f"Training set size: {len(X_train)}")
print(f"Testing set size: {len(X_test)}")
# Out:
# Training set size: 19826
# Testing set size: 4957

# %% [markdown]
# ## Tokenization and padding
#
# - Fit a `Tokenizer` on training text only.
# - Convert texts to integer sequences.
# - Choose `max_length` as the 95th percentile of training sequence lengths.
# - Pad sequences to a fixed length for Keras models.
#
# - *_Using the 95th percentile avoids very long outliers while keeping most sequences intact._*

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Initialize the Tokenizer
tokenizer = Tokenizer()

# Fit the tokenizer on the training data
tokenizer.fit_on_texts(X_train)

# Convert text to sequences
X_train_sequences = tokenizer.texts_to_sequences(X_train)
X_test_sequences = tokenizer.texts_to_sequences(X_test)

# Determine the maximum sequence length based on the 95th percentile
max_length = int(np.percentile([len(seq) for seq in X_train_sequences], 95))

# Apply padding to the sequences
X_train_padded = pad_sequences(X_train_sequences, maxlen=max_length, padding='post')
X_test_padded = pad_sequences(X_test_sequences, maxlen=max_length, padding='post')

print(f"Vocabulary size: {len(tokenizer.word_index) + 1}")
print(f"Maximum sequence length: {max_length}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778405044.189923   49757 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1778405044.496285   49757 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778405045.719777   49757 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Vocabulary size: 28571
# Maximum sequence length: 19

# %% [markdown]
# ## Encode the labels
#
# - Encode string labels into integer IDs using `LabelEncoder`.
# - Keep the class mapping (`label_encoder.classes_`) for interpretation later.
#
# - *_This converts labels into a format compatible with `sparse_categorical_crossentropy`._*

# %%
# encode the labels
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

print("Encoded labels:", np.unique(y_train_encoded))
print(label_encoder.classes_)
# Out:
# Encoded labels: [0 1 2]
# ['hate speec' 'neither' 'offensive language']

# %% [markdown]
# ### Define Common Callbacks for models
#
# - Define a reusable callbacks bundle used by all models.
# - Save best checkpoints and stop early when validation loss stops improving.
#
# - **_Keeping callbacks consistent makes model comparisons fairer._**

# %%
# callbacks 
from tensorflow import keras
import os

os.makedirs('./model_checkpoints', exist_ok=True)

PATIENCE = 3

def callbacks(model_name: str): 
    """Create common training callbacks (checkpoint + early stopping).

    Args:
        model_name (str): Filename to save under `./model_checkpoints/`.

    Returns:
        list[keras.callbacks.Callback]: Callbacks for `model.fit()`.
    """
    return [
        keras.callbacks.ModelCheckpoint(
            filepath=f'./model_checkpoints/{model_name}',
            save_best_only=True,
            monitor='val_loss'
        ),
        keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=PATIENCE
        )
]

# %% [markdown]
# ## Build Sequential RNN, with trainable Embedding layer
#
# - Build a simple baseline sequence model: Embedding -> SimpleRNN -> Softmax.
# - Train it with the same preprocessing, split, and callbacks used by other models.
#
# - **_This baseline helps quantify how much LSTM and pretrained embeddings improve performance._**

# %%
# 1. Simple RNN with a trainable Embedding layer.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Input

# Model 1: Simple RNN with trainable Embedding layer
model1 = Sequential([
    Input(shape=(max_length,)),

    Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=100
    ),

    SimpleRNN(64),

    Dense(3, activation='softmax') # number of classes is 3, so we use softmax activation
])

model1.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy', # use sparse_categorical_crossentropy for integer labels
    metrics=['accuracy']
)

model1.summary()
# Out:
# I0000 00:00:1778405049.683786   49757 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4143 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 19, 100)        │     2,857,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │        10,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,867,855 (10.94 MB)
#  Trainable params: 2,867,855 (10.94 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history1 = model1.fit(
    X_train_padded,
    y_train_encoded,
    epochs=30,
    callbacks=callbacks("simple_rnn.keras"),
    batch_size=32,
    validation_data=(X_test_padded, y_test_encoded)
)
# Out:
# Epoch 1/30
# I0000 00:00:1778405051.185802   53467 service.cc:153] XLA service 0x395edb30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778405051.185820   53467 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 3050 6GB Laptop GPU, Compute Capability 8.6 (Driver: 13.2.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.21.1)
# I0000 00:00:1778405051.222026   53467 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778405051.348872   53467 cuda_dnn.cc:461] Loaded cuDNN version 92101
# I0000 00:00:1778405051.366677   53467 dot_merger.cc:481] Merging Dots in computation: sequential_1_simple_rnn_1_while_body_1291_grad_1446_const_0__.21.clone.clone.clone.clone.clone.clone.clone
# I0000 00:00:1778405051.366755   53467 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1930__.24
# I0000 00:00:1778405051.654394   53467 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1778405051.997076   53565 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_29', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1778405052.179910   53467 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1778405052.544985   53556 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 16 bytes spill stores, 16 bytes spill loads
#  42/620 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7007 - loss: 0.7878
# I0000 00:00:1778405053.552744   53467 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 607/620 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8191 - loss: 0.5271
# I0000 00:00:1778405056.436676   53468 dot_merger.cc:481] Merging Dots in computation: sequential_1_simple_rnn_1_while_body_1291_grad_1446_const_0__.21.clone.clone.clone.clone.clone.clone.clone
# I0000 00:00:1778405056.436741   53468 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1930__.24
# I0000 00:00:1778405056.604257   53468 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1778405056.988136   53646 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_29', 12 bytes spill stores, 12 bytes spill loads
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.5247
# I0000 00:00:1778405059.077301   53460 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1778405059.424268   53776 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_10', 12 bytes spill stores, 12 bytes spill loads
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8624 - loss: 0.4122 - val_accuracy: 0.8935 - val_loss: 0.3369
# Epoch 2/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9426 - loss: 0.1755 - val_accuracy: 0.8376 - val_loss: 0.4910
# Epoch 3/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9813 - loss: 0.0590 - val_accuracy: 0.8665 - val_loss: 0.4856
# Epoch 4/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9914 - loss: 0.0273 - val_accuracy: 0.8586 - val_loss: 0.5910

# %% [markdown]
# ## Build LSTM model with trainable Embedding layer
#
# - Replace the SimpleRNN recurrent layer with an LSTM layer (same embedding setup).
# - Train and evaluate using the same pipeline for a clean architecture comparison.
#
# - **_LSTMs typically handle longer dependencies better than vanilla RNNs.**_

# %%
# LSTM with a trainable Embedding layer.
from tensorflow.keras.layers import LSTM

model2 = Sequential([
    Input(shape=(max_length,)),
    
    Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=100
    ),
    
    LSTM(64),
    Dense(3, activation='softmax')
])

model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy', # use sparse_categorical_crossentropy for integer labels
    metrics=['accuracy']
)

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 19, 100)        │     2,857,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        42,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,899,535 (11.06 MB)
#  Trainable params: 2,899,535 (11.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history2 = model2.fit(
    X_train_padded,
    y_train_encoded,
    epochs=30,
    batch_size=32,
    callbacks=callbacks("simple_lstm.keras"),
    validation_data=(X_test_padded, y_test_encoded)
)
# Out:
# Epoch 1/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8694 - loss: 0.3850 - val_accuracy: 0.8945 - val_loss: 0.3004
# Epoch 2/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9293 - loss: 0.2144 - val_accuracy: 0.8959 - val_loss: 0.3346
# Epoch 3/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9608 - loss: 0.1230 - val_accuracy: 0.8850 - val_loss: 0.3369
# Epoch 4/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9784 - loss: 0.0700 - val_accuracy: 0.8618 - val_loss: 0.4439

# %% [markdown]
# ## Build LSTM with pretrained Word2Vec embeddings.
#
# - Load pretrained Word2Vec vectors (Google News 300d).
# - Build an embedding matrix aligned with the tokenizer vocabulary.
# - Initialize the Keras Embedding layer from this matrix and freeze it to test transfer via embeddings.
#
# - **_Goal: test whether pretrained semantics improves macro-F1 under class imbalance._**

# %% [markdown]
# ### Load pretrained vectors

# %%
# LSTM with pretrained Word2Vec embeddings.
import gensim.downloader as api

word2vec = api.load("word2vec-google-news-300")

# %% [markdown]
# ### Build embedding matrix

# %%
embedding_dim = 300 # dimension of the word vectors 

embedding_matrix = np.zeros(
    (len(tokenizer.word_index) + 1, embedding_dim)
) # initialize the embedding matrix with zeros

for word, i in tokenizer.word_index.items():
    if word in word2vec:
        embedding_matrix[i] = word2vec[word] # fill the embedding matrix with the pretrained word vectors

# %%
# build LSTM model with pretrained embeddings
model3 = Sequential([
    Input(shape=(max_length,)),

    Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=embedding_dim,
        weights=[embedding_matrix
    ],
        trainable=False # freeze the embedding layer
    ),

    LSTM(64),
    Dense(3, activation='softmax')
])

model3.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy', # use sparse_categorical_crossentropy for integer labels
    metrics=['accuracy']
)

model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 19, 300)        │     8,571,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,664,935 (33.05 MB)
#  Trainable params: 93,635 (365.76 KB)
#  Non-trainable params: 8,571,300 (32.70 MB)

# %%
history3 = model3.fit(
    X_train_padded,
    y_train_encoded,
    epochs=30,
    batch_size=32,
    callbacks=callbacks("lstm_pretrained.keras"),
    validation_data=(X_test_padded, y_test_encoded)
)
# Out:
# Epoch 1/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8698 - loss: 0.3707 - val_accuracy: 0.8884 - val_loss: 0.3342
# Epoch 2/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8942 - loss: 0.2893 - val_accuracy: 0.8886 - val_loss: 0.3076
# Epoch 3/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9013 - loss: 0.2692 - val_accuracy: 0.8963 - val_loss: 0.2949
# Epoch 4/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9083 - loss: 0.2524 - val_accuracy: 0.8927 - val_loss: 0.2899
# Epoch 5/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9119 - loss: 0.2387 - val_accuracy: 0.8945 - val_loss: 0.2905
# Epoch 6/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9150 - loss: 0.2290 - val_accuracy: 0.8943 - val_loss: 0.2859
# Epoch 7/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9198 - loss: 0.2154 - val_accuracy: 0.8909 - val_loss: 0.2980
# Epoch 8/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9246 - loss: 0.2051 - val_accuracy: 0.8955 - val_loss: 0.3164
# Epoch 9/30
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9278 - loss: 0.1947 - val_accuracy: 0.8923 - val_loss: 0.3181

# %% [markdown]
# ### Model accuracy and loss visualization
#
# - Plot accuracy/loss curves for each trained model.
# - Use these curves to spot overfitting/underfitting and convergence differences.
#
# - **_These plots support the discussion section in the written report._**

# %%
import matplotlib.pyplot as plt

def plot_history(history, model_name, save_path=None): 
    """
    This function plots the training and validation accuracy and loss curves for a given model history.
    """

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Accuracy subplot
    axes[0].plot(history.history['accuracy'])
    axes[0].plot(history.history['val_accuracy' ])

    axes[0].set_title(f'{model_name } Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend(['Train', 'Validation' ])

    # Loss subplot
    axes[1].plot(history.history['loss' ])
    axes[1].plot(history.history['val_loss'])

    axes[1].set_title(f'{model_name } Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend(['Train', 'Validation' ])

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=150)
    plt.show()

# %%
titles = [
    "Simple RNN",
    "Simple LSTM",
    "LSTM with Pretrained Embedding"
]

histories = [history1, history2, history3]

save_paths = [
    './outputs/figures/training_curves/simple_rnn_curves.png',
    './outputs/figures/training_curves/lstm_curves.png',
    './outputs/figures/training_curves/lstm_w2v_curves.png',
]

os.makedirs('./outputs/figures/training_curves', exist_ok=True)
for i, history in enumerate(histories):
    plot_history(history, titles[i], save_path=save_paths[i])

# %% [markdown]
# ## Evaluation and Error analysis
#
# - Evaluate each model on the held-out test set.
# - Report accuracy, confusion matrix, and a classification report (including macro averages).
# - Inspect a few misclassified examples for error analysis.
#
# - **_Macro metrics are important here because the dataset is imbalanced._**

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
)
import matplotlib.pyplot as plt
import numpy as np
import os

def evaluate_model(
    model,
    X_test,
    y_test,
    encoder,
    model_name
):
    y_pred = model.predict(X_test)
    y_pred_classes = y_pred.argmax(axis=1)

    accuracy = accuracy_score(y_test, y_pred_classes)
    print(f" {model_name} Accuracy: {accuracy:.4f}")

    cm = confusion_matrix(y_test, y_pred_classes)
    print("Confusion Matrix:")
    print(cm)

    print("Classification Report:")
    report = classification_report(
        y_test, y_pred_classes,
        target_names=encoder.classes_,
        output_dict=True,
    )
    print(classification_report(
        y_test, y_pred_classes,
        target_names=encoder.classes_,
    ))

    # Save confusion matrix figure
    plt.figure(figsize=(6, 5))
    plt.imshow(cm, cmap='Blues')
    plt.title(f'{model_name} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(range(len(encoder.classes_)), encoder.classes_, rotation=30, ha='right')
    plt.yticks(range(len(encoder.classes_)), encoder.classes_)
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, cm[i, j ], ha='center', va='center', fontsize=9)
    plt.tight_layout()
    os.makedirs('./outputs/figures/confusion_matrices', exist_ok=True)
    plt.savefig(f'./outputs/figures/confusion_matrices/{model_name.lower().replace(" ", "_")}_cm.png', bbox_inches='tight', dpi=150)
    plt.show()

    macro = report.get('macro avg', {})
    return accuracy, y_pred_classes, macro.get('precision'), macro.get('recall'), macro.get('f1-score')

# %%
# evaluate model1: Simple RNN
_, y_pred_classes_model1, macro_precision_model1, macro_recall_model1, macro_f1_model1 = evaluate_model(
    model1,
    X_test_padded,
    y_test_encoded,
    label_encoder,
    titles[0]
)
# Out:
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#  Simple RNN Accuracy: 0.8586
# Confusion Matrix:
# [[  46   37  207]
#  [  12  633  190]
#  [ 140  115 3577]]
# Classification Report:
#                     precision    recall  f1-score   support
#
#         hate speec       0.23      0.16      0.19       290
#            neither       0.81      0.76      0.78       835
# offensive language       0.90      0.93      0.92      3832
#
#           accuracy                           0.86      4957
#          macro avg       0.65      0.62      0.63      4957
#       weighted avg       0.85      0.86      0.85      4957

# %%
# evaluate model2: Simple LSTM
_, y_pred_classes_model2, macro_precision_model2, macro_recall_model2, macro_f1_model2 = evaluate_model(
    model2,
    X_test_padded,
    y_test_encoded,
    label_encoder,
    titles[1]
)
# Out:
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#  Simple LSTM Accuracy: 0.8618
# Confusion Matrix:
# [[ 120   33  137]
#  [  27  702  106]
#  [ 261  121 3450]]
# Classification Report:
#                     precision    recall  f1-score   support
#
#         hate speec       0.29      0.41      0.34       290
#            neither       0.82      0.84      0.83       835
# offensive language       0.93      0.90      0.92      3832
#
#           accuracy                           0.86      4957
#          macro avg       0.68      0.72      0.70      4957
#       weighted avg       0.88      0.86      0.87      4957

# %%
# evaluate model3: LSTM with pretrained embeddings
_, y_pred_classes_model3, macro_precision_model3, macro_recall_model3, macro_f1_model3 = evaluate_model(
    model3,
    X_test_padded,
    y_test_encoded,
    label_encoder,
    titles[2]
)
# Out:
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#  LSTM with Pretrained Embedding Accuracy: 0.8923
# Confusion Matrix:
# [[  75   29  186]
#  [  32  697  106]
#  [  77  104 3651]]
# Classification Report:
#                     precision    recall  f1-score   support
#
#         hate speec       0.41      0.26      0.32       290
#            neither       0.84      0.83      0.84       835
# offensive language       0.93      0.95      0.94      3832
#
#           accuracy                           0.89      4957
#          macro avg       0.72      0.68      0.70      4957
#       weighted avg       0.88      0.89      0.89      4957

# %% [markdown]
# ## Error Analysis and discussion
#
# - Printed a few misclassified examples.
# - Compare true vs predicted labels and annotate likely causes (short context, sarcasm, overlap between classes).
#
# - _**This supports the qualitative discussion in the report.**_

# %%
for i in range(len(y_pred_classes_model1)):
    if y_pred_classes_model1[i] != y_test_encoded[i]:
        print("Tweet:", X_test.iloc[i])
        print("Actual:", y_test_encoded[i])
        print("Predicted:", y_pred_classes_model1[i])
        print("---")
# Out:
# Tweet: rt eanahs__ 1inkkofrosess lol credit ain t near good know right man job ho nice though
# Actual: 1
# Predicted: 2
# ---
# Tweet: nien_nunb search gay redneck episode 1 play
# Actual: 0
# Predicted: 2
# ---
# Tweet: keebithalal loganswarning gotta love islamofascist cow try make retort age typical muzzie idiocy
# Actual: 0
# Predicted: 1
# ---
# Tweet: 8220 ashlynwynns mud shark black friends make perfect sense 128514 128557 128514 128557 idiotic 8221
# Actual: 1
# Predicted: 2
# ---
# Tweet: allsportsbruh say waste draft pick manziel mallet that s tell delete account retard
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt letsargueboxing staycoolwheels scream like little bitch lmaooo
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt rihannahasaids aight game over dyke ruin http t co o0can6gb1p
# Actual: 0
# Predicted: 1
# ---
# Tweet: ain t real nigga without goal chase yellow bone bitch w toe paint
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt wolfpackalan oreos first twist it you aw crap break
# Actual: 2
# Predicted: 1
# ---
# Tweet: iamshady_ that s even real word must hit blunt start make shit nigger ass lol
# Actual: 0
# Predicted: 2
# ---
# Tweet: day care take kitty nap hosers
# Actual: 1
# Predicted: 0
# ---
# Tweet: niggas ain t playin gram defense man george need tell bitch ass niggas man
# Actual: 0
# Predicted: 2
# ---
# Tweet: nobody planet earth protective bull dyke
# Actual: 2
# Predicted: 1
# ---
# Tweet: god damn bird
# Actual: 2
# Predicted: 1
# ---
# Tweet: the_red_sea shethetruththo bitch yo muthafukin ass react vain females tweet amp dont context dumb ass dont neither
# Actual: 2
# Predicted: 0
# ---
# Tweet: fuck yellow cloud do
# Actual: 2
# Predicted: 0
# ---
# Tweet: san_sim lol avila simple live pretty redneck area never get pronounce correctly
# Actual: 2
# Predicted: 1
# ---
# Tweet: thejokerxo porn star 100 acceptable bro im talk air mattress hoe lol
# Actual: 2
# Predicted: 1
# ---
# Tweet: afternoon group trash besides bubba keegs furyk group thememorialtournament
# Actual: 1
# Predicted: 2
# ---
# Tweet: wish coulda say emmaleeeparkerr tonight good see fag 128540
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt nandagorgeous rt like bmth adtr ptv ymas sws atl om amp m aa miw btf wcar mcr afi pe bvb wim bc ss cte nsn gd watic aa bfmv fob f 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: kuntakayne never see ignorant illiterate piece shit life bring natl guard amp disperse trash bassem_masri
# Actual: 0
# Predicted: 2
# ---
# Tweet: hate white trash try act like equal make much clearer white trash be
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt dirtyskimask lmaooo friday next 8220 1stname_bravo like yo son s fag 8221
# Actual: 0
# Predicted: 2
# ---
# Tweet: virtually zero protections lgbtq persons alabama lot acceptance either think queer alabamian kid today
# Actual: 1
# Predicted: 2
# ---
# Tweet: people call complain spinellis purge special lmao pussies louisvillepurge
# Actual: 2
# Predicted: 0
# ---
# Tweet: doemostdope mattrbennett209 johnniegoings ha booner twitter boone_boone5356 ha
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt torahblaze 1sonofyahweh hell yea know what s wrong w brothas love cave hoe damn much stopitnow
# Actual: 2
# Predicted: 0
# ---
# Tweet: chink_19 shut chink
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt _2kkz faggit bitch try say hoe d hd bearfaced bitch yusa fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: jesuschrist straight gt that s faggot kill him period sonofgod gt
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt tittyflex sell pussy dirt together fell put blast even though the 8230
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt rockprincess818 go fight idf progressive trash hate much gut it istandwithisr 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: jpantsdotcom todd__kincannon the__realtony partial faggot homo both fairly describe sick twist assholes there
# Actual: 0
# Predicted: 2
# ---
# Tweet: bryanstars atl bvb sws ptv relapse symphony set off farewell love mayday parade fob paramore etc
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt bankheist retard shawnacarr99
# Actual: 0
# Predicted: 2
# ---
# Tweet: get do bike dyke
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt _tiffnasty y all niggas entertain nicole bitch see y all ever take bitch post naked pics serious 8230
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt toddknife full weakenednachos set except last song southern darkness fest last month who s ape guitar https t c 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: ilovebamf big long lose brother swear know without wetback
# Actual: 2
# Predicted: 1
# ---
# Tweet: case day get better wife s rav 4 flat redneck put 16 inch rim go 200x2
# Actual: 1
# Predicted: 2
# ---
# Tweet: obamac0re like peaceful that s bore like fight come ghetto remember p impossible
# Actual: 1
# Predicted: 2
# ---
# Tweet: still really confuse humplayproblems think lucricus fag dagger
# Actual: 0
# Predicted: 2
# ---
# Tweet: alyssawiens faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: nurbstheocho8 tori_mills02 dyke anything 128111 128539 128109
# Actual: 2
# Predicted: 0
# ---
# Tweet: zaneisclasker fuck r talk tell go tell nigga love white bitch gtf bro
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt obamastrawman joan rivers say gay michelle tranny perhaps death accident see clinton s ron brown vin 8230
# Actual: 2
# Predicted: 1
# ---
# Tweet: ayefuckwoody coryburgess87 literally eat asshole live actually faggot seem little confuse
# Actual: 0
# Predicted: 2
# ---
# Tweet: part award like dyke part cypher amp old skool female mcs
# Actual: 2
# Predicted: 0
# ---
# Tweet: sometimes even gotta tell hoe grow smh
# Actual: 1
# Predicted: 2
# ---
# Tweet: much makeup trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: rich light skin coon expect
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt villagebae hate faggot talk shit block can t respond bitch write letter response an 8230
# Actual: 0
# Predicted: 2
# ---
# Tweet: 8220 queendev_ leave trash 128552 8221 128557 128557 128557 sick
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt jpayneancap a_m_perez sybilll diannewing2 velvethammer mylibertymygun sdalexander11 aoakleyc bet new york yankee prog 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt david_marchese johnny cash turn the gambler guess could say know ho never mind http t co gmk 8230
# Actual: 2
# Predicted: 1
# ---
# Tweet: 8220 dnumberbefore2 8220 vice504fly dnumberbefore2 regular nig play b 8221 lol ima b ig famous 8221 these days count somethin
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt inkmyholebody nigga fuckin faggot https t co e3m6tujnhf
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt males_thoughts bitch ass chick flick ever sad movie http t co o0sk0sm40f
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt eisenbackemily hate people leave trash car
# Actual: 2
# Predicted: 1
# ---
# Tweet: tell tho if when nigger women start get cornrows again mannn
# Actual: 2
# Predicted: 0
# ---
# Tweet: mrmooncricket atblackface uncleunco bobbybotsods fuckthemallcops racistnegro69 ugly gay nigga bitch fuck peace shit
# Actual: 0
# Predicted: 2
# ---
# Tweet: autyaut_ miss you eat speak miss red bone cook 128553 128553 128553 128525 128525 128525 128542
# Actual: 1
# Predicted: 2
# ---
# Tweet: 25 years support niggas bitch kid well gratitude die
# Actual: 2
# Predicted: 0
# ---
# Tweet: amarierubio chink eye
# Actual: 0
# Predicted: 2
# ---
# Tweet: try call sorry ass cousin msparka1 27th bday hoe ain t answer like always big time days lol
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt blacknerdjade rt fivefifths hell wrong yall rt twantargaryen pecan pie sweet potato pie trash http t co hh50p5pytx
# Actual: 2
# Predicted: 1
# ---
# Tweet: mayormcginn usmayors senfeinstein white people need weapons defend subhuman trash sort unleash us
# Actual: 1
# Predicted: 0
# ---
# Tweet: pussy lie pussy 128175 128175
# Actual: 2
# Predicted: 0
# ---
# Tweet: mr_lewis_ brookebrooklyn_ ohh yaa want brooke pinkie toe bang coffee table twat lol
# Actual: 2
# Predicted: 1
# ---
# Tweet: xzimpx prophzilla twitter fag also retard
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt illusivehaven shhhh 8230 wrap around let kiss bruise heart lick unhealed wound taste raw wild ho 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: sit bar work watch walk dead fuck wetbacks decide come amp turn spic music jesus christ
# Actual: 0
# Predicted: 2
# ---
# Tweet: hat hoodrat chicks ghetto anxiety attack formal events
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt timatheracer wow another faggot 8220 shinobicelsius timatheracer wow another cam hater lol 8221 gt gt dat dude nice
# Actual: 0
# Predicted: 2
# ---
# Tweet: equality law people white black red yellow blue homo s hetero s well draw line http t co ugzyrtkabw
# Actual: 2
# Predicted: 1
# ---
# Tweet: get eye red bone
# Actual: 1
# Predicted: 2
# ---
# Tweet: darthdanaa yes retard
# Actual: 0
# Predicted: 2
# ---
# Tweet: zlarge20 bro next year make look like straight trash enjoy little time leave
# Actual: 2
# Predicted: 1
# ---
# Tweet: omg cutest little tinker bell ever 10084 65039 http t co vdajfvlwyp http t co yptz9o4sis
# Actual: 1
# Predicted: 0
# ---
# Tweet: rt dumbto polly want cracker dumbto http t co zc8mlwneuc
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt imakittttyy make homemade chili cornbread dinner watch supernatural fave boys happy saturday bitch http 8230
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt virleehol cbinflux well sure heck know read read trash right almost everything hear web 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: kinghov1313 boi stop aint hoe 11th ward never either thats nobody know hood be aint hoe
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt ag2pearl black americans worse bho http t co k4iweugnyx well research article bind elicit cry uncle tom 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: jaytwofly huh lol mad nigger mad
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt kiaranicole_x _joaries kash_wingatelfc chanchan_ox babes buy brazilian peruvian bengali
# Actual: 1
# Predicted: 2
# ---
# Tweet: snivel little cunt would embarrass cant stand guy joederosacomedy thecumiashow
# Actual: 2
# Predicted: 0
# ---
# Tweet: confuse circumstances seem get way high ho virgo http t co nraai6dhvx
# Actual: 1
# Predicted: 2
# ---
# Tweet: nyjusdntgaf like nig come home ever want
# Actual: 0
# Predicted: 2
# ---
# Tweet: 4 old hoe ponk dyke outchea girl talk
# Actual: 0
# Predicted: 2
# ---
# Tweet: gook boy shawty http t co laaahstyeb
# Actual: 1
# Predicted: 0
# ---
# Tweet: would like apologize anyone call fat stupid gay nigger jew retard truly sorry jk troll fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: rbigwood hollywood underwood take shirt start scream dark hah like horror movie nip
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt ohsodestinee 8220 idoclyfe ouija movie look like trash 8221 really good
# Actual: 1
# Predicted: 2
# ---
# Tweet: sorry fo da rant make mad ashamed color wish white y all would like
# Actual: 0
# Predicted: 2
# ---
# Tweet: thattallcashier lol youre retard 128514
# Actual: 2
# Predicted: 0
# ---
# Tweet: eleycome_eleygo caykelly16 movies matter long coon shit coons nigga
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt jakelewis44_ luv deez hoe 128527 http t co ofjlxao5sf
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt donthypeme 8220 vsamone 8220 donthypeme favorites yellow album 8221 all it 8221 theperfectanswer 127942
# Actual: 1
# Predicted: 2
# ---
# Tweet: gonzalez_sassy ur sassy white trash change ur username
# Actual: 0
# Predicted: 2
# ---
# Tweet: trust say jesuschrist would kill faggot come back life today s day age gt spartacus rome
# Actual: 0
# Predicted: 2
# ---
# Tweet: starkfreeordie i fuckin want out gt tire bullshit faggot ass closet racist wannabe commune without railroad state gt cali
# Actual: 0
# Predicted: 2
# ---
# Tweet: softestmuffin torahblaze _tee13 billy goat hillbillies suck amp fuck disgraceful brazzen face unabashed pig
# Actual: 2
# Predicted: 0
# ---
# Tweet: hate people tell many tattoo make look ugly like bitch fuck
# Actual: 0
# Predicted: 2
# ---
# Tweet: sudden crave hell oreo cookies
# Actual: 2
# Predicted: 1
# ---
# Tweet: opalrose4ursoul duckydynamo trethreat band negro
# Actual: 2
# Predicted: 1
# ---
# Tweet: charlesbarrkley hey sir house nigger uncle tom grand ole mississippi rest case
# Actual: 0
# Predicted: 2
# ---
# Tweet: mayarsharkawi fake pics http t co jtwuu9cysr get tl r dismiss muzzie darknight420 jewjitsugrl begbie_1 efilnikcufecin7
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt erikcochrane tonydecola 128514 128514 nig
# Actual: 0
# Predicted: 2
# ---
# Tweet: on top that pregnant ass sorry hoe aint never get money even water break talltrappin88 riptallt
# Actual: 2
# Predicted: 0
# ---
# Tweet: coffincreepxx throw faggot word smh smh smh
# Actual: 0
# Predicted: 2
# ---
# Tweet: chill zahra im get crackers rn
# Actual: 2
# Predicted: 1
# ---
# Tweet: bitch ass hoe ass nigga prolly get pussy
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt marrybel_ maybe yall hoe ass niggas start consider girls feelings shiii think nigga do 8230
# Actual: 2
# Predicted: 0
# ---
# Tweet: sick coon antic rt poonsoaker accuracy rt thotcho 8220 henny gt water 8221 128128 128128 128128
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt i_floodsyatl zariavonmars um http t co cuue9vvc2m exactly hoe twat setup
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt thexbone twitch play call duty enter trash talk chat auto aim rest
# Actual: 1
# Predicted: 2
# ---
# Tweet: itsyour_man make white trash cousin fucker
# Actual: 2
# Predicted: 0
# ---
# Tweet: aldofelix naw dude wish white trash
# Actual: 0
# Predicted: 1
# ---
# Tweet: lmaooo naw man rt diponline yo want rt humbltonbanks serious bro lol rt cheezmoejenkinz 2 3 10am early bird special
# Actual: 1
# Predicted: 2
# ---
# Tweet: repulsivetool band suck worse live fag gun amp pose
# Actual: 0
# Predicted: 2
# ---
# Tweet: jaredreve use monkey maker prick
# Actual: 2
# Predicted: 1
# ---
# Tweet: maxwell_larsen cunt
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt alleycelestine 8220 viridoesitt kissin small lips trash lol 8221 yessssss
# Actual: 1
# Predicted: 2
# ---
# Tweet: stop smokin bathsalt charlie brown rejectedpeanutsspecials
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt kamri_notoyota 8220 felz_ king fire rt vianawf king ti vs tip troubleman albums trash 8221 def
# Actual: 2
# Predicted: 1
# ---
# Tweet: 0ddment could fuck bowl graham cracker cereal
# Actual: 2
# Predicted: 0
# ---
# Tweet: word understand blackjesus nigger heavily disappoint show aaronmacgruder stuff blow imo
# Actual: 0
# Predicted: 1
# ---
# Tweet: oh trash say trash gonna keep drive thru ky 8220 corey_emanuel lifeasking trash gotta ignore her 8221
# Actual: 2
# Predicted: 1
# ---
# Tweet: deeznutsdoe hate feel like faggot punk ass hoe
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt pointstacked follow fag shinsnipes birthday today
# Actual: 2
# Predicted: 0
# ---
# Tweet: stay faithful room full hoe
# Actual: 2
# Predicted: 0
# ---
# Tweet: kobe fat amp im white 9996 rt jwill252 people retard lol rt thetrackmamba y all really think kobe fat tho give break
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt rontheanchorman girl tweet you might ghetto bring food outside movies might stupid pay 4 99 8230
# Actual: 2
# Predicted: 1
# ---
# Tweet: drboycewatkins1 coons monkey like disgust me minstrel show negro cry shit time disgrace everywhere
# Actual: 0
# Predicted: 2
# ---
# Tweet: ramboutit 8220 master11_ 20tolife_ ramboutit hoe austin 8221 teach us austin i teach get curve that s know
# Actual: 1
# Predicted: 2
# ---
# Tweet: mis_sarahd basedpapi1017 tranny
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt versacesilk try tell grandpa 70s music trash https t co kyulqzobc6
# Actual: 1
# Predicted: 2
# ---
# Tweet: kathleen_herne stink shut hole amp perform trick like good train monkey
# Actual: 1
# Predicted: 2
# ---
# Tweet: feel like black people niggers black nigger imma tell you idc
# Actual: 2
# Predicted: 0
# ---
# Tweet: thewagnerer fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: datachick humanity really need get past whole slow stare scene accident ape mentality
# Actual: 1
# Predicted: 2
# ---
# Tweet: niccas hat tho lol let live homie
# Actual: 2
# Predicted: 0
# ---
# Tweet: 8220 juniormaye8 lot though attitudes pure trash 8221 teamwhitegirls swirltheworld
# Actual: 1
# Predicted: 2
# ---
# Tweet: chasebasford chase god damn faggot 128514 128557 128514 128557
# Actual: 0
# Predicted: 2
# ---
# Tweet: fuck christ hate tutor tas literally get pay teach retard stop pick nose get fuck outta face
# Actual: 0
# Predicted: 2
# ---
# Tweet: jwreich142 steveworks4you teabaggers extremely dumb
# Actual: 2
# Predicted: 1
# ---
# Tweet: fluffy retard homeboy call baby rattlesnake friend kiss him baby rattlers kill man 128563 http t co pwfo8jhaoa
# Actual: 2
# Predicted: 1
# ---
# Tweet: punk ass cop jus bulldogged bitch https t co sceoqiqbme
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt brittanyaflores get niggas amp get bitch 128080
# Actual: 2
# Predicted: 0
# ---
# Tweet: its_makepeace donno demz iz ima bout get white gurll ghetto asses find out
# Actual: 2
# Predicted: 1
# ---
# Tweet: already know wilson go hoe later let go get ammo
# Actual: 2
# Predicted: 0
# ---
# Tweet: rino trash like speakerboehner karlrove frankluntz see conservatives democrat party see black slave property tcot
# Actual: 0
# Predicted: 2
# ---
# Tweet: mitt romney go take away weave become president hoe go walkin around look like lil bill amp calliou
# Actual: 2
# Predicted: 0
# ---
# Tweet: can t fuck scary hoe
# Actual: 0
# Predicted: 2
# ---
# Tweet: jacobbbacker faggot
# Actual: 2
# Predicted: 0
# ---
# Tweet: rivenbarkyahoo hale_razor jim hogg county dirt poor democrat lean county hebronville seat near ghetto
# Actual: 2
# Predicted: 1
# ---
# Tweet: deiukesionai like emily little twat
# Actual: 2
# Predicted: 1
# ---
# Tweet: god tweet ghetto
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt rollingwithtrin 1 2 3 4 many niggers store knowwww steal 128514 128514 128514
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt ssparklesdaily beautiful women meet bruise souls tire eye amp quiet smile survivors ones know abo 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: nigga gotta find hoe quick
# Actual: 2
# Predicted: 0
# ---
# Tweet: kentucky fry cater da white folk color menu
# Actual: 1
# Predicted: 2
# ---
# Tweet: grizzboadams roid rage much faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt menshumor kim kardashian baby in important news take trash last night
# Actual: 1
# Predicted: 2
# ---
# Tweet: amandabynes give clothe look like cute dyke
# Actual: 0
# Predicted: 2
# ---
# Tweet: sir please go text mexican bitch finna deal witcho childish ass 128514
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt nicoromero23 edm music trash af annoy
# Actual: 1
# Predicted: 2
# ---
# Tweet: apaches 30 mm round turn jihadis tomato soup markrothschild1 rockprincess818 nofear3136 lanna70115
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt ghostattics what bank show engagement queer community hire trans women
# Actual: 0
# Predicted: 2
# ---
# Tweet: huntermoore bout ike couple hours
# Actual: 1
# Predicted: 0
# ---
# Tweet: iowahawkblog jjauthor gt davidmasciotra get past boot camp go active years see really daily liberal pussy
# Actual: 0
# Predicted: 2
# ---
# Tweet: austinburge44 either way school trash 128521
# Actual: 1
# Predicted: 2
# ---
# Tweet: jose soto reflections former gay teabagger http t co xtmmuzyk
# Actual: 1
# Predicted: 0
# ---
# Tweet: destrothenoble nekolin purple amp pink for faggot want protect by police instead bear arm need be
# Actual: 0
# Predicted: 1
# ---
# Tweet: past week paula dean uncle lose job say nigger bullllllshiiiiitttt
# Actual: 2
# Predicted: 1
# ---
# Tweet: police niccas tryn raid da trap
# Actual: 2
# Predicted: 0
# ---
# Tweet: jai s hate jay completely irrational hahaha still love jai though need someone call faggot call someone fag
# Actual: 2
# Predicted: 0
# ---
# Tweet: fugazi3011 leave beaner retard
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt mr_jsmart24 man would happy fat bitch chipotle atlanta get clowney 8230 but go cost go get happy w 8230
# Actual: 2
# Predicted: 0
# ---
# Tweet: edgarpixar overdose heavy drug sound bad tonight pussy shit every day
# Actual: 1
# Predicted: 2
# ---
# Tweet: can t talk anyone go answer little phone call little bitch low bathroom foh
# Actual: 2
# Predicted: 0
# ---
# Tweet: bretvondehl younow fuck bitch shit load hate first broadcast
# Actual: 2
# Predicted: 0
# ---
# Tweet: bros hos bros without hos
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt i_be_koolz food good except rice cook bitch monday week tootsies
# Actual: 1
# Predicted: 2
# ---
# Tweet: patriotsorg screw ragheads
# Actual: 0
# Predicted: 1
# ---
# Tweet: smh rt _sirhampton_ shit trash rap rt waymothegod legend gonna replace cudi joint like http t co fgaqf7qlw3
# Actual: 2
# Predicted: 0
# ---
# Tweet: vinceschilling vince general feel natives know regard term redskins offensive not
# Actual: 2
# Predicted: 1
# ---
# Tweet: stuff like oreo http t co mpajkwjbzp
# Actual: 2
# Predicted: 1
# ---
# Tweet: call sandy wind go make lot girls clam really sandy
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt kaprecesun 2 favorite jiggers at s_hawn24 satisfied_x 128514 128514 128514 https t co unnm233mfq
# Actual: 1
# Predicted: 2
# ---
# Tweet: kip tokuda yellow guy work niggerize seattle pd die bad there s another pos hide wing replace him
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt divamonroe2uhoe niggas always wanna talk god gays pussy eat last night ain t god ag 8230
# Actual: 0
# Predicted: 2
# ---
# Tweet: flow935 jus want let y 225 ll know hope hurricane kill soca sunday trash lordwillin
# Actual: 0
# Predicted: 1
# ---
# Tweet: plasticdom plz go starbucks that ebola sound like really ghetto hood name tbh
# Actual: 2
# Predicted: 1
# ---
# Tweet: fuck pussy ass hater go suck dick die quick someone me youtube comment think good friends
# Actual: 0
# Predicted: 2
# ---
# Tweet: con t also provide color stickers place nametags members indicate prefer pronouns
# Actual: 1
# Predicted: 2
# ---
# Tweet: trash rt vibemagazine notorious b i g 8217 s son cj wallace rap watch amp vote here http t co 3kzjj7nqpp http t co wownc0a70p
# Actual: 1
# Predicted: 2
# ---
# Tweet: wondertrade best pokemon feature ever get level 27 japanese wobbuffet level 4 begin area trash pokemon
# Actual: 1
# Predicted: 0
# ---
# Tweet: 128557 128557 128557 rt esckmotrent swear niggas use step one foot bus bitch would like nextttt 128553 128514 128514 http t co xjkudt4bub
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt milesm_05 ghetto girls start fight 128514 https t co wykh16plek
# Actual: 2
# Predicted: 1
# ---
# Tweet: karmendanielle_ aka wanna keep warm shoulda introduce coons
# Actual: 1
# Predicted: 0
# ---
# Tweet: spend money want bitch business
# Actual: 2
# Predicted: 0
# ---
# Tweet: delete bitch ass nigga rt quanny_quan redskins beat us delete fuck ig
# Actual: 0
# Predicted: 2
# ---
# Tweet: call faggot one lol
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt thefakeespn red hot chili pepper longest nip slip super bowl half time show history
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt athietechamp destroy team talk trash game gt gt 128076
# Actual: 2
# Predicted: 1
# ---
# Tweet: dont think women wear flesh tone color pant lol
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt itschee_ whip https t co ucv3hrjatv
# Actual: 1
# Predicted: 2
# ---
# Tweet: would bitch weather bipolar gonna appreciate nice instead
# Actual: 1
# Predicted: 2
# ---
# Tweet: victoria_star1 haha monkey feet i like it but 4 real feet magical back it smooth every nook cranny tightness
# Actual: 1
# Predicted: 2
# ---
# Tweet: richxinxflavor fag gtfo
# Actual: 0
# Predicted: 2
# ---
# Tweet: nomeek_justmilz trash yr 3 4 waive lol
# Actual: 1
# Predicted: 2
# ---
# Tweet: lmfaoooo rt harleyyyquinn_ wiz perfect example fame get bitch look like typical tweaker homeless woman
# Actual: 2
# Predicted: 0
# ---
# Tweet: late hell niggas really hat cuz hoe want lightskin dude jail y all crazy
# Actual: 2
# Predicted: 0
# ---
# Tweet: lovin hoe thats bitch put pipe in suckin dick thats bitch give goodnight kiss
# Actual: 2
# Predicted: 0
# ---
# Tweet: jonsweethearts argie
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt skraw_berry oh would ve stand up fall back hoe
# Actual: 2
# Predicted: 1
# ---
# Tweet: hood negros deserve bail money way visit jail
# Actual: 0
# Predicted: 1
# ---
# Tweet: probably save kingborgman s ass today gas diesel engine 128514 would without redneck friends 128514 128514
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt tomolson8 1dittlinger redneck write lol drunks use gravity get 128563
# Actual: 2
# Predicted: 1
# ---
# Tweet: need bitch drop niggah
# Actual: 0
# Predicted: 2
# ---
# Tweet: pipe_tyson me nigga pussy get hand dawg
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt nerdatcooltable rt realsheembacc every bad bitch nigga treat like shit amp yet stay wanna
# Actual: 0
# Predicted: 2
# ---
# Tweet: faggot rant night
# Actual: 0
# Predicted: 2
# ---
# Tweet: saucygyro back nigger music decent
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt toxicityy1 gwen stefani s new single trash her hilary duff britney fergie give go raise kid judg 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: barry s whitey brownshirts run wild oakland follow lead n w a punks chant f police http t co 9nburmtj
# Actual: 1
# Predicted: 2
# ---
# Tweet: just_joshin7 fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: photo give trailer park trash transformthursday ladykimora vegasqueens vegasshowgirls http t co ljejfufulk
# Actual: 1
# Predicted: 2
# ---
# Tweet: sheehey back door cut still go un guard iu hoosierhoops hoosiers
# Actual: 1
# Predicted: 2
# ---
# Tweet: fucc primo aint nobody ask 2 fav dink lie
# Actual: 2
# Predicted: 1
# ---
# Tweet: one name offensive kike wop kraut wetback jigaboo towelhead gook redskin
# Actual: 0
# Predicted: 1
# ---
# Tweet: badshah200 ur pal stlabubadu threat2 apostate kufar gt i cld cut ur neck w sword islam amp watch squeal like bitch like daniel pearl
# Actual: 0
# Predicted: 2
# ---
# Tweet: bullskickass decide bullsnation retard love
# Actual: 2
# Predicted: 0
# ---
# Tweet: r amp b trash compare early 2000 s
# Actual: 1
# Predicted: 2
# ---
# Tweet: know fuck bitch little hoe gt lt
# Actual: 0
# Predicted: 2
# ---
# Tweet: bigbootybishopp white_thunduh lassen cc coach want me feel youll get nig doubt
# Actual: 0
# Predicted: 2
# ---
# Tweet: tylercarboner hey leave abbey too oh get job slope might move back cause id lose lot money buy ticket
# Actual: 1
# Predicted: 2
# ---
# Tweet: 127867 127867 127867 127804 128153 127913 plus sheryl crow http t co 49kywznotu
# Actual: 1
# Predicted: 2
# ---
# Tweet: lololol joey lattimes phone call retard
# Actual: 2
# Predicted: 1
# ---
# Tweet: fuck hate niggers bruh http t co oetk4f94bo
# Actual: 0
# Predicted: 2
# ---
# Tweet: fat ass hoe hold machine
# Actual: 0
# Predicted: 2
# ---
# Tweet: asshole_king pat owner kike
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt drecordero always interest see people trash la liga react products la liga premier league club
# Actual: 1
# Predicted: 2
# ---
# Tweet: gas always cheaper ghetto
# Actual: 1
# Predicted: 2
# ---
# Tweet: hot isis social media photo laugh jihadis get baby kick sever head 8211 warn graphic http t co 7zr8daxng4 tcot pjnet
# Actual: 2
# Predicted: 1
# ---
# Tweet: revolutionuk_ jesus would love muzzie torturers fuck animal savage
# Actual: 0
# Predicted: 2
# ---
# Tweet: mrnwachukwu naw boys trash start coast
# Actual: 2
# Predicted: 1
# ---
# Tweet: keep away frm charlie day rt jhonenv life like someone s favorite part body disgust knees
# Actual: 1
# Predicted: 2
# ---
# Tweet: big_jim777 happy birthday dirty little bird 128520 tear 127867 127881 127880
# Actual: 1
# Predicted: 2
# ---
# Tweet: upenn campus black chicks trash gonna pay
# Actual: 0
# Predicted: 1
# ---
# Tweet: ghetto
# Actual: 2
# Predicted: 1
# ---
# Tweet: huntermoore juicy pussy
# Actual: 2
# Predicted: 0
# ---
# Tweet: yer gonna continue contrarian bitch go die then time trifle
# Actual: 0
# Predicted: 2
# ---
# Tweet: ruby ugly bunga bunga
# Actual: 1
# Predicted: 2
# ---
# Tweet: think change 9733 doctor s advocate 9733 cunt go mental hmm
# Actual: 2
# Predicted: 1
# ---
# Tweet: mikecheck_123 favorite drink white trash everywhere
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt jasminee_gamboa hoe hoe
# Actual: 0
# Predicted: 2
# ---
# Tweet: can t worry bout bitch ain t worry bout
# Actual: 2
# Predicted: 0
# ---
# Tweet: alanmilner morning_joe alqueda use cell phone internet wow teabaggers stupid
# Actual: 2
# Predicted: 1
# ---
# Tweet: hahahhahaa rt princebama boyfriend trash ma stop tryna convince otherwise tweet
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt quirkisms jeter a rod class trash
# Actual: 2
# Predicted: 1
# ---
# Tweet: dropdeadfred11 money get good weed always best pussy sorry friend guess
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt hollygolawly can t wait eat metropole 21ccincinnati see 21clouisville friends bring damn yellow penguins ro
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt buckm00se dont get draft squad gonna problems drop faggot jesus
# Actual: 0
# Predicted: 2
# ---
# Tweet: hate extra ass bitch extra ass nigga much stop unnecessary
# Actual: 2
# Predicted: 0
# ---
# Tweet: hey go look video man find kidnap girls ohio what nigger shitmybosssays
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt amoz1939 drink last drop wash teapot haiku mijikai
# Actual: 1
# Predicted: 2
# ---
# Tweet: smh amp amp bitch bitch ass niggahs
# Actual: 2
# Predicted: 0
# ---
# Tweet: acmobbdeep madsbennett yeah run squirrels coons
# Actual: 1
# Predicted: 2
# ---
# Tweet: 8220 mutateroos seminoles redskins k 8221 seminole tribe get agreement them fsu pay use name
# Actual: 2
# Predicted: 1
# ---
# Tweet: brrrrangadang nigga 128529 128529 know damn well coon
# Actual: 0
# Predicted: 2
# ---
# Tweet: chemicalkidss bitch look like fuck white trash trailer park queen lookin man bear pig http t co fqyxljyiet
# Actual: 0
# Predicted: 2
# ---
# Tweet: look little faggot kellz622 tell beautiful much can make smile
# Actual: 0
# Predicted: 2
# ---
# Tweet: 8220 whattheffacts orangutan try sex actress julia roberts 8221 smart monkey 128514
# Actual: 2
# Predicted: 1
# ---
# Tweet: markhalperin wsjopinion barackobama anything trash black president
# Actual: 0
# Predicted: 1
# ---
# Tweet: yaremisxo whatever neymar trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt jarhead44 hi buy margarita sure so like way barstool show clam
# Actual: 2
# Predicted: 1
# ---
# Tweet: dinneny goddamn bird try say yoburger better 5 guy
# Actual: 2
# Predicted: 1
# ---
# Tweet: alicia112794 basically like background music fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: prefer jameis winston speak tv all damn coon
# Actual: 0
# Predicted: 2
# ---
# Tweet: s_roach happy birthday nicca coon shit responsible way
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt blacknerdjade rt parkour_lewis last 5 hours rt the_blueprint last hour half work trash exist
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt boburnham future gay culture consider cool america s teens instead wiggers straggots
# Actual: 0
# Predicted: 1
# ---
# Tweet: 6 07 bout match wit dis nicca donnydinero
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt jakeg_basedgod never go full retard
# Actual: 1
# Predicted: 2
# ---
# Tweet: bae make deep fry oreos 128523
# Actual: 2
# Predicted: 1
# ---
# Tweet: many bitch one sentence fixitjesus
# Actual: 0
# Predicted: 2
# ---
# Tweet: soon fuckeveryword fuck backtrack can t wait fuck faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: george rockwell 2 3 speech lynchberg armo 8230 http t co 5lfxmdyu2g proud say uncle kelly speech 63
# Actual: 1
# Predicted: 0
# ---
# Tweet: pussy aint shit product either gonna get onna muscle gotta pay
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt countermoonbat btw hillary huge supporter law admit lie stupid rub about need aske 8230
# Actual: 2
# Predicted: 1
# ---
# Tweet: walk dead trash people all 128514
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt heidil_rn fuck islam pigfucking trash troll itsjustme7o7 mzkerievans ctbauza
# Actual: 0
# Predicted: 2
# ---
# Tweet: flame faggot publicly state want everything hand them like fuck dude get bottom ass something
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt jaymesshaylan fuuck jalens slow bitch
# Actual: 0
# Predicted: 2
# ---
# Tweet: jaytwofly g_mucka good leave stupid faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: 27 weeks straight nigga mcm get bitch y all fuck 128514 128514 128514 128514
# Actual: 2
# Predicted: 0
# ---
# Tweet: kyleefagnola call cock block faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: someone part jam x white trash cultist
# Actual: 0
# Predicted: 2
# ---
# Tweet: son 9 still issue tie shoe barefoot time case want know hillbilly status
# Actual: 1
# Predicted: 2
# ---
# Tweet: want punch throat get order wrong stupid bitch sonic
# Actual: 0
# Predicted: 2
# ---
# Tweet: lowworldsfinest 1stblock_thomas man y all niggas chill man high af tho y all niggas ain t even tell hoe 128564 9995
# Actual: 2
# Predicted: 0
# ---
# Tweet: watch_scenario yeah better play ya nigger
# Actual: 0
# Predicted: 2
# ---
# Tweet: hate ghetto trash special school across street build grow criminals
# Actual: 0
# Predicted: 1
# ---
# Tweet: swagishsternes yea listen hoe wake
# Actual: 2
# Predicted: 0
# ---
# Tweet: trash guess get tire chalmers trash start rt everybodyhatesx chalmers lose job norris cole lmfaoooo
# Actual: 2
# Predicted: 1
# ---
# Tweet: mike_ray7 congratulations officially fuck retard
# Actual: 0
# Predicted: 2
# ---
# Tweet: grizzboadams fuck block white ass try start shit like fuck queer fuck nigga
# Actual: 0
# Predicted: 2
# ---
# Tweet: somebody couldve like aye man drop money nooooooo fuck break faggot selfish bastards hate yall
# Actual: 0
# Predicted: 2
# ---
# Tweet: lmao drake bullshit serena williams wallah look like tranny
# Actual: 2
# Predicted: 0
# ---
# Tweet: itsjaylaaa eat shit nigga bitch turd bag dick beetle
# Actual: 0
# Predicted: 2
# ---
# Tweet: look like tool useful clay hammer fag hoppondis http t co k7wqlawrwm
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt chip216 kid listen nas show new perspective come ghetto like me pimp c 128081 128081 128081
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt vatxn illegal alien race crime muchomacho mcdonalds jeandeaux1776 cspanwj wetbacks http t co pf2ypelyop
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt thachosenkid321 donquixtote trash tbh startmikevike
# Actual: 1
# Predicted: 2
# ---
# Tweet: already tire mr stupid af decide show us video trigonometric notions um yeah want say hoe
# Actual: 0
# Predicted: 2
# ---
# Tweet: everyone say letsmakeitawkward queer justmadeitawkward
# Actual: 2
# Predicted: 0
# ---
# Tweet: bloggerboxing rianscalia pass foster faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: twice divorce teabagger florida attorney general say marriage reserve stable endure family units http t co wafg8eyygm
# Actual: 1
# Predicted: 0
# ---
# Tweet: itsmander kfc always get da color folk back da cage wit da kfc
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt k1mb0slyc3 too 8220 whatsashirt defiantly go see new planet ape tonight 8221
# Actual: 1
# Predicted: 2
# ---
# Tweet: gullible ones do rt reaganchanel people go college intentions hoe k
# Actual: 2
# Predicted: 1
# ---
# Tweet: cant afford winter clothe rt da_1eye_creep summer hoe winter muslimah
# Actual: 1
# Predicted: 2
# ---
# Tweet: kristin12909 better nig lol anything ill flip 10 something im tryna get cash
# Actual: 0
# Predicted: 2
# ---
# Tweet: kieffer_jason go hurt bitch ass feelings
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt cuzimdaddy_ 5feet_0inches dis wrong _100d fuck wit lame nigga lame bitch
# Actual: 0
# Predicted: 2
# ---
# Tweet: 8220 mikeypdacav5 love song john doe dope 8221 mirandawigley edenbaby101 faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: haseenabakhtali steen020 madraq altyd zo geweest hoe vaak men ook zegt dit nooit meer lozewoorden puntjebijpaaltje vertonen z dierngedrag
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt bloggerboxing no matter go there s always asshole wear yankees cap sounds_good_bro http t co tbgyikpv1e
# Actual: 2
# Predicted: 1
# ---
# Tweet: get 50 pound bag dawg mutts
# Actual: 1
# Predicted: 2
# ---
# Tweet: like niggas try come im like bitch dont shit pussies
# Actual: 0
# Predicted: 2
# ---
# Tweet: msoltan18 koredeb9 suck tho mad trash carry you always 0 point
# Actual: 1
# Predicted: 2
# ---
# Tweet: get another nigga s bitch bed right
# Actual: 2
# Predicted: 0
# ---
# Tweet: 8220 _honeysays phone charge backwards 128533 8221 retard
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt sheemteam97 fuck islamic state kill cunts 127468 127463
# Actual: 0
# Predicted: 2
# ---
# Tweet: comedyposts harlem shake excuse go full retard 30 second
# Actual: 2
# Predicted: 1
# ---
# Tweet: ovoshubham fuck bitch bout get bitch ass nigga stupid ass
# Actual: 0
# Predicted: 2
# ---
# Tweet: niggas actin like hoe em bitch
# Actual: 0
# Predicted: 2
# ---
# Tweet: mlvassallo oh really fag gross aid infect sick fuckers
# Actual: 0
# Predicted: 2
# ---
# Tweet: ghetto thuged version tree life come soon
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt kiss_mybeautyy rather argue amp make 128536 fight 128074 128165 128162 amp break 127939 128131 9996 65039 cause 128166 thirsty bitch 128111 love see happy 128522 127969 home fuc 8230
# Actual: 2
# Predicted: 0
# ---
# Tweet: oh well fag anyways
# Actual: 0
# Predicted: 2
# ---
# Tweet: sit alone watch white chicks pant fuzzy blanket tea turn
# Actual: 1
# Predicted: 2
# ---
# Tweet: get h 228 agen dazs ice cream bar whole lot make sure chocolate gotta chocolate man popcorn red popcorn graham crackers
# Actual: 1
# Predicted: 2
# ---
# Tweet: black twitter need get paul george dick impregnate stripper wiz do tyga do kanye turn hoe housewife
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt kxrxsxb know one person could say anything look think you re retard stfu stupidbitches
# Actual: 0
# Predicted: 1
# ---
# Tweet: jants clutch bedtime tho 128514 128557
# Actual: 1
# Predicted: 2
# ---
# Tweet: good morning coons
# Actual: 0
# Predicted: 1
# ---
# Tweet: lemme find bitch nigga talk shit
# Actual: 0
# Predicted: 2
# ---
# Tweet: cowboys 6 1 bitch cowboysnation another great win ilove team
# Actual: 2
# Predicted: 0
# ---
# Tweet: diversity chcgo blck pstr flood w dth threats ovr endorsement gop candidate 8220 u sellout uncle tom ass n gger 8221 http t co vcbwzkyedv
# Actual: 0
# Predicted: 1
# ---
# Tweet: cotton_candy9 god write em think coon
# Actual: 2
# Predicted: 1
# ---
# Tweet: lmaoooo rt toeknee2gx lol ok pal rt acehudsonjr bitch go tell no tuh http t co toea3czjdf
# Actual: 2
# Predicted: 0
# ---
# Tweet: dis nicca lame
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt ariesspears young cat draft nba today walk lotto ticket wait till niggas find pussy come 8230
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt gmb_ace get money nigga da hoe love
# Actual: 0
# Predicted: 2
# ---
# Tweet: moneydriven 2manylouboutins glad uncle another stupid faggot world hopefully next
# Actual: 0
# Predicted: 1
# ---
# Tweet: rt jeffgallardo9 8220 sonali1123 guy color eye 128525 8221 http t co hwiplpuxpq
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt tibaburger sick ass goal ned worldcup2014
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt sportscenter yankees survive 9th inning scare beat rangers 12 11 8226 gardner 4 5 hr rbi 3 r 8226 teixeira 1 2 hr 2 rbi 3 r htt 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: ima home tomorrow line bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: impactparasite fuckin roast faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: atspace 2 3 nigga hoe suck wayans brothers funny jamie foxx number 2
# Actual: 0
# Predicted: 2
# ---
# Tweet: early bitch drive denton omg move already
# Actual: 1
# Predicted: 2
# ---
# Tweet: elizabeth a stupid hoe
# Actual: 0
# Predicted: 2
# ---
# Tweet: itskeeshkapeesh yourself faggot buy dictionary
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt morningmoneyben image peshmerga give heave ho isis flag really brighten friday kick sorry butt http 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt badnradbrad whattheflocka lol see ike kindergarten teacher start sexual relationship
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt thecrewfinest 187xo_ niggah thecrewfinest func fucccccccked upppppp 128514 i m on
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt bidenshairplugs anybody trash neighborhood perceive injustice fuck moron ferguson
# Actual: 0
# Predicted: 2
# ---
# Tweet: portlandia putabirdonit rt mightymouse105 xbox one would much cooler put bird
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt a1lovely_ least say im crazy some nigga gotta find bitch wild shoot ass 128514
# Actual: 0
# Predicted: 2
# ---
# Tweet: 8220 iamkrause see every iftheygunnedmedown tweet http t co xwmkac1aw6 8221 dis like da color brady bunch
# Actual: 1
# Predicted: 2
# ---
# Tweet: get granny long johns rednecks for cold bone cold polar vortex sequel dog http t co zxuxfxpzi7
# Actual: 2
# Predicted: 1
# ---
# Tweet: bitch wear leggings everyday sick know y all wear pair 3 days row can t fool
# Actual: 2
# Predicted: 0
# ---
# Tweet: frustration bitch
# Actual: 1
# Predicted: 2
# ---
# Tweet: get faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: high hoe hit bowl nigga rick riprick
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt perspective_pic retweet see bird http t co o7rexl0teu
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt fant4stic63 kid say much parent pay everything rt andrea_michele pay every bill can t complain abo 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt judiebaby_ vnxthny attention keshonna alexander best pussy world taste good asf 128523 128523 128525 128536 128079 128588 128514 128514 128514 128553 128540 128523 128523 128525 128525
# Actual: 2
# Predicted: 1
# ---
# Tweet: mrfoolycooly dont think celestial dragon kill
# Actual: 1
# Predicted: 2
# ---
# Tweet: beepbeepamanda today talk like pirate day absolutely nobody know id charlie morton impersonation day
# Actual: 1
# Predicted: 0
# ---
# Tweet: slow reply make feel like retard want put foot wall hjhdyhdhlgjdftilh
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt roulettista mertesacker say give ghetto fist still goat
# Actual: 1
# Predicted: 2
# ---
# Tweet: vinniepolitan kill coons
# Actual: 0
# Predicted: 1
# ---
# Tweet: steveworks4you how much knob gobble one day youre head blockhead be
# Actual: 2
# Predicted: 1
# ---
# Tweet: oh coon bike week charlotte ok make sense
# Actual: 1
# Predicted: 2
# ---
# Tweet: kincade00 watch watch tv hoe
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt buckm00se abel 43 yrs old beaner work home depot want hang major l
# Actual: 1
# Predicted: 2
# ---
# Tweet: act like casper get ghost bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: inform crunk ain t dead ho 8230 lol okay sure
# Actual: 2
# Predicted: 1
# ---
# Tweet: fat dyke make want vomit
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt lexataughtyou hedge_brandon calm bitch touch boob amp ill dick amp staple forehead since wanna a 8230
# Actual: 2
# Predicted: 0
# ---
# Tweet: 8220 maxwell_larsen live gay can t afraid two black dicks butt fuck queer
# Actual: 0
# Predicted: 2
# ---
# Tweet: ur trash http t co 6kn7pztgl8
# Actual: 2
# Predicted: 1
# ---
# Tweet: 8220 glitteredinpink west305 like 5 8 need to 8221 1 hoe 2 5 10 breaking11 3 suck dick
# Actual: 0
# Predicted: 2
# ---
# Tweet: the_red_sea stop cover yo goddamn face like kkk yo yung silly ass sign pussy
# Actual: 2
# Predicted: 0
# ---
# Tweet: kensuttling mr cox the chase charlie day bend boy while conjugate a e
# Actual: 2
# Predicted: 1
# ---
# Tweet: run ball offensive coordinator retard
# Actual: 1
# Predicted: 2
# ---
# Tweet: go wife bitch let niggas lick head public
# Actual: 2
# Predicted: 0
# ---
# Tweet: waanderlusting id chink leave blue ball
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt navyasslos hunter hurt helmsley rt rich_gmi cut imaginary height shit women tweet sleep alone every nig 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: horny call ask buy drink morning jiggaboo walk sonic drink hand do
# Actual: 1
# Predicted: 2
# ---
# Tweet: prophzilla hate blow 3005 like hipster hate faggot say love music base worst
# Actual: 0
# Predicted: 2
# ---
# Tweet: chink really hunt food rt wwltv dog shoot arrow n o east http t co q1kqt6stwl
# Actual: 0
# Predicted: 2
# ---
# Tweet: wiganzlad markycrumb gmail_shorts way http t co mqczuxlbtt love chav hot sexy scally fucker
# Actual: 2
# Predicted: 0
# ---
# Tweet: douche cub redneck cub fan freak ask bite bloody berk like the 8230 http t co ulc6cmvtki
# Actual: 1
# Predicted: 2
# ---
# Tweet: nyrkelsmads wishin local take da yankee game spoil
# Actual: 1
# Predicted: 2
# ---
# Tweet: forte truck dude hoe ass lol
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt sirstern claim whatever part please fuck bliss bruise sweet pussy crop till beg filthy 8230
# Actual: 2
# Predicted: 0
# ---
# Tweet: neighborhood rt clairelea18 know mexcian ghetto when http t co 1vq0ocrsev
# Actual: 1
# Predicted: 2
# ---
# Tweet: quilzel that s rednecks erecycle http t co 6lrxiqsi8b
# Actual: 2
# Predicted: 0
# ---
# Tweet: stfu redneck white trash head ass
# Actual: 2
# Predicted: 0
# ---
# Tweet: cokamoschiach_ defense trash rock jesus soto karass diego chaves
# Actual: 1
# Predicted: 2
# ---
# Tweet: dish_answers gots da bet da msnbc wit dat color reverend listen coloreds else miss
# Actual: 0
# Predicted: 2
# ---
# Tweet: happy bro happy ho happy husband key marriage c study think so http t co kknd87mv4b http t co kag0xfdd1s
# Actual: 2
# Predicted: 1
# ---
# Tweet: soldier1eaodgrn teabagger scum want threaten people penis extender danger country
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt zach_dorsey trash worth
# Actual: 1
# Predicted: 2
# ---
# Tweet: much ucla team beat trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: asshole_king oh no draft gay ass come tv well welcome redskins nation queer lot niggers
# Actual: 0
# Predicted: 2
# ---
# Tweet: raunchy ass hoe
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt menstruai hear bitch tell story think 8220 lie lie lie 8221 128530
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt hunneemolassess legs dont rub together mean pwoosy trash hear this
# Actual: 2
# Predicted: 1
# ---
# Tweet: can t fuck coon ass girl bruh
# Actual: 2
# Predicted: 0
# ---
# Tweet: niggas bitch hoe bitch ion see difference
# Actual: 2
# Predicted: 0
# ---
# Tweet: old bitter salty ass niccas make flesh crawl bone bitch be dontarguejustacceptit
# Actual: 0
# Predicted: 2
# ---
# Tweet: yo bitch dick come crib get pass around love
# Actual: 0
# Predicted: 2
# ---
# Tweet: use call mom japs younger lol asian racial slur
# Actual: 1
# Predicted: 2
# ---
# Tweet: niggas wear wigs bitch days
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt iroib come nudes trash get big titties http t co 1weypg8rer
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt hawkblogger afc trash last season especially afc south jag could make playoff push great draft jo 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: itsmegrizz dink uknow thats true
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt imneverchillin yo phone go class amp teacher say turn trash off one songs yo mixtape http t 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: love fuckin wit people givin greedy ass nigas old crackers wit expire cheese dey callin like 8221 nigga im shittin likea goose
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt breely216 recommend serve size brownies all them
# Actual: 1
# Predicted: 2
# ---
# Tweet: jaaaaaade__ shut up miss fag
# Actual: 2
# Predicted: 0
# ---
# Tweet: you 8217 re little bitch rt fuckingcashbro rt thotcho team get blow super bowl
# Actual: 0
# Predicted: 2
# ---
# Tweet: buckm00se joe cortez ultimate faggot fight prove
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt rakwonogod rare pic trash pose trash http t co usgiazsdwv
# Actual: 2
# Predicted: 1
# ---
# Tweet: dream job pedophile dress like mickey mouse hug kid day
# Actual: 2
# Predicted: 1
# ---
# Tweet: brice2254 fuck you faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt uncleblazer yo mama ghetto use cigarette butt q tip
# Actual: 1
# Predicted: 2
# ---
# Tweet: really phone kinda guy actually hate talk phone amp texting kinda trash also
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt guinness_ras chelsea_elisa tell choose a trash environment try save like hypocritical douc 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: type special faggot bring chocolate swishers smoke session
# Actual: 0
# Predicted: 2
# ---
# Tweet: gt _ lt rt itstheboomshow fricknawesome metal monkey ball
# Actual: 2
# Predicted: 1
# ---
# Tweet: dumb bitch https t co we46wo15ni
# Actual: 0
# Predicted: 2
# ---
# Tweet: sonnen faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: wake new shit like fuck bitch shit
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt sammi_boyden fuck jam try tell jawga boys suck go ape shit dude savanigga officialdthrash jawgaboyz
# Actual: 0
# Predicted: 2
# ---
# Tweet: dumb black bitch get card picture make fuck mad ruin day 128545 128545 128074 128298 128163
# Actual: 0
# Predicted: 2
# ---
# Tweet: king_albert21 ceto_13 ha ha look fag say lol
# Actual: 2
# Predicted: 0
# ---
# Tweet: wassup wit fucc niccas
# Actual: 0
# Predicted: 2
# ---
# Tweet: nah nomeek_justmilz 128514 128514 128514 128514 yo think some1 photoshopped face faggot smmfh i hate yall http t co 5e2fkq3q2t
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt pluggedinpiff thoughtsofrandy stop follow bad bitch ya get spammed
# Actual: 2
# Predicted: 0
# ---
# Tweet: hbt2013mm ask question support border jumpers support illegals
# Actual: 1
# Predicted: 2
# ---
# Tweet: blacclabelle_ 9786 65039 nice avi lil nigger
# Actual: 2
# Predicted: 0
# ---
# Tweet: duh aka shitty nights rt linaahmadi city nights hella ghetto
# Actual: 2
# Predicted: 0
# ---
# Tweet: kincade00 owe anyway hoe need interest shoot shit
# Actual: 2
# Predicted: 0
# ---
# Tweet: izzayy_bitches amp 4th guinea pig haunt
# Actual: 2
# Predicted: 1
# ---
# Tweet: firefighter job white trash
# Actual: 0
# Predicted: 2
# ---
# Tweet: __trail__ take like tamu bitch jump 6 beat sc ain t good thejournalist44 that1guyjeff
# Actual: 2
# Predicted: 0
# ---
# Tweet: killdion h_christianne politics twitter coon lol
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt grind2times think even real relationship i think real trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: hmu talmbout match pull 30 niccas wit ya 128530
# Actual: 1
# Predicted: 2
# ---
# Tweet: someone probably tell 6 god trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: cookies crackers even level
# Actual: 1
# Predicted: 2
# ---
# Tweet: rihanna s favorite thing white house visit my president black http t co 86zvjuzjlr solidarity poke whitey not wise
# Actual: 2
# Predicted: 1
# ---
# Tweet: missyy_j happy birthday bitch 10084 65039 127881
# Actual: 2
# Predicted: 0
# ---
# Tweet: never friends entire time live virginia one cool me hope white trash southerners die
# Actual: 0
# Predicted: 1
# ---
# Tweet: englishbrit123 sound like good idea want word spread jews niggers commies alike
# Actual: 0
# Predicted: 2
# ---
# Tweet: aj2amazing obispo ho big
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt itssongoku get spirit bomb lil nigga rt leanandcuisine dragonball z trash debate want
# Actual: 2
# Predicted: 0
# ---
# Tweet: grizzboadams ight nigga haha fuck queer clear schedule
# Actual: 0
# ...
# Actual: 1
# Predicted: 2
# ---
# Tweet: 8 16 14 mo govjaynixon let 8220 kill crackers kill baby new black panthers hijack ferguson presser http t co z2wko9ripz
# Actual: 0
# Predicted: 1
# ---
# Tweet: chanelisabeth nigger music
# Actual: 0
# Predicted: 2
# ---
# Tweet: huntermoore hells yeah fuckin sick ass bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: that1guyjeff thank you hate you eat poison fall down run face first wall yankees miss playoffs
# Actual: 2
# Predicted: 1
# ---
# Tweet: open cloud part silk gt can get room southside ghetto
# Actual: 2
# Predicted: 1
# ---
# Tweet: typically hateful anti christian mentally ill ugly dyke trash pig couple jennifer mccarthy melisa erwin http t co tw9nl5hkmt
# Actual: 0
# Predicted: 1
# ---
# Tweet: ok bitch say wut think she say believe describe urself dumbass
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt 1trikofficial itsnotadam prob def good early set energy tool want tune in http t co hxfjwy3jab less ho 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt jjauthor us ghettos drive liberal ideology forge unions amp bankrupt self serve dems cater parasites tcot http 8230
# Actual: 0
# Predicted: 1
# ---
# Tweet: word doe gm rt shik702 good morning it s celebration bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: clinchmtn316 sixonesixband america today rule thumb be doubt blame whitey
# Actual: 0
# Predicted: 2
# ---
# Tweet: lose 0 3 sterling31 that s try do stupid yardie
# Actual: 1
# Predicted: 2
# ---
# Tweet: nobody care fuck fag damn bring bitch water even though youre thirsty fuck 128514 128514 128514 fucknigga
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt ratchet2english girl tweet you might ghetto bring food outside movies might stupid pay 4 99 8230
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt chrisbegettinit 8220 _100d like zero bitch nap that s gon stick yo side fall 128175 8221 forreal tho lie 128175
# Actual: 2
# Predicted: 0
# ---
# Tweet: matt_petrie22 geta life faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt clutchlikemj tennessee even orange like vitamin pee yellow 128553 128514 128514 128514
# Actual: 1
# Predicted: 2
# ---
# Tweet: dolfyadolf y all gots betta machinery fo dat hanger ghetto
# Actual: 1
# Predicted: 2
# ---
# Tweet: hand game zebra jack asses save us trouble watch
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt tittyflex lol need halloween dress like ho know myself everyday another opportunity
# Actual: 2
# Predicted: 1
# ---
# Tweet: little scrawny white boys play ghetto rap music walk around
# Actual: 2
# Predicted: 0
# ---
# Tweet: ncrusade godmaniac_ come wage us fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: get sleepy phone act retard
# Actual: 1
# Predicted: 2
# ---
# Tweet: nekolin destrothenoble naaaa faggot so i guess around long would ya
# Actual: 2
# Predicted: 0
# ---
# Tweet: theshardyrebel faggot
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt huhwhatsacondom would never happen non color award show betawards http t co rujnu1l7t8
# Actual: 1
# Predicted: 2
# ---
# Tweet: kaylahprettymom lmao girlllaaaa like em chunky anymore 128514 128514 128514 128514 128567
# Actual: 1
# Predicted: 2
# ---
# Tweet: dyke bitch kill thinkin really get hoe lol
# Actual: 0
# Predicted: 2
# ---
# Tweet: billythathird matt_sliwinski copy tweet ginzo
# Actual: 1
# Predicted: 2
# ---
# Tweet: jessie andrews best girl girl scenes porn love way make bitch cum
# Actual: 2
# Predicted: 0
# ---
# Tweet: boy yung thug fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: damn cold fo color man
# Actual: 1
# Predicted: 2
# ---
# Tweet: krispy717 grizzboadams fuck gay faggot look gay ass pink shirt haha
# Actual: 0
# Predicted: 2
# ---
# Tweet: ayy carlton ghetto school switchedatbirth
# Actual: 0
# Predicted: 2
# ---
# Tweet: nyrkelsmads never survive da color hood
# Actual: 1
# Predicted: 2
# ---
# Tweet: joeylattime mawson38 americ00n joey r retard defense allow avg like 10 point really need
# Actual: 2
# Predicted: 0
# ---
# Tweet: make wise argument accelerate warholian notion celebrity era vine pass teens mock old wrinkle ball
# Actual: 2
# Predicted: 1
# ---
# Tweet: _triggaplease_ nigger hello
# Actual: 2
# Predicted: 0
# ---
# Tweet: soxdawg rawr rt skinrubberboi my sexy french scally love him frenchscally http t co 5idq3r5akz sexy scally woof woof
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt michaelgt03 happy birthday freshman faggot cooopster98 chase123456718
# Actual: 0
# Predicted: 2
# ---
# Tweet: real niggas bad bitch 2 things common ignorant fuck amp neither know kings queen
# Actual: 2
# Predicted: 0
# ---
# Tweet: morbidmermaid work today niglet
# Actual: 0
# Predicted: 2
# ---
# Tweet: adrian1_knowsu 9757 65039 no ghetto name 128581
# Actual: 1
# Predicted: 2
# ---
# Tweet: itsmander sure ain t color
# Actual: 2
# Predicted: 1
# ---
# Tweet: you ain t bitch favorite response long texts
# Actual: 2
# Predicted: 0
# ---
# Tweet: pussy gotta trash rt adolfhibsta love life sad lol rt cqminaj im glad khloe k dump french s ghetto ass
# Actual: 2
# Predicted: 1
# ---
# Tweet: wendydavistexas gregabbott_tx support illegals come spread disease among americans dream bitch
# Actual: 0
# Predicted: 2
# ---
# Tweet: joh2guy love racism blame whitey everything mention it bet white man put desert tortoise bundyranch
# Actual: 0
# Predicted: 1
# ---
# Tweet: asshole_king pills nig last 4 years like magic j that nig hav die years ago y all first team draft gay
# Actual: 0
# Predicted: 2
# ---
# Tweet: 18 yr scrap might get life prison murderin norte nigga el pollo loco story rd 128563
# Actual: 2
# Predicted: 1
# ---
# Tweet: porn android iphone ipad sex xxx teen cutie lesbian teens toy slit http t co zs05enjjwm
# Actual: 1
# Predicted: 2
# ---
# Tweet: black bitch kickin school bitch still comin wit durags still head nd shit
# Actual: 0
# Predicted: 2
# ---
# Tweet: im_thirst randies fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: every gook losangeles deport kill
# Actual: 0
# Predicted: 1
# ---
# Tweet: grandma macon rinky dink mosquito fill cop infest swamp lmao
# Actual: 1
# Predicted: 2
# ---
# Tweet: two red bone kissin n da back seat
# Actual: 1
# Predicted: 2
# ---
# Tweet: coons can t wait wear oreo j s
# Actual: 0
# Predicted: 1
# ---
# Tweet: youngjeezy get feelin like trappin ain t dead get ready call guala salute da truth seenitall seenitalltheautobiography
# Actual: 1
# Predicted: 2
# ---
# Tweet: hop dis come severe shock use color
# Actual: 1
# Predicted: 2
# ---
# Tweet: maddslander 128514 welcome back b without daily rant tl trash af
# Actual: 1
# Predicted: 2
# ---
# Tweet: photo anarcho queer 8220 anarchism stand social order base free group individuals for http t co iy6gro4t8z
# Actual: 1
# Predicted: 2
# ---
# Tweet: devilfzyq devilelyie tehdevilclan shut fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: rabehchararah1 lmaoo fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: cumkwats thank base pee slit
# Actual: 1
# Predicted: 2
# ---
# Tweet: gingerdemoness jcapswgr dem color boys sayin dare baby daddy gots protect semen da lock key wrap 2x
# Actual: 2
# Predicted: 1
# ---
# Tweet: omoide yokocho shinjuku tokyo japan jap 243 n lose japan miguel mich 225 n http t co 7j2uxi5501
# Actual: 1
# Predicted: 2
# ---
# Tweet: infidelalie read suck bacon encrust middle finger muslim twats
# Actual: 0
# Predicted: 2
# ---
# Tweet: https t co jtlzergxi0 leo get fuck vine fag
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt dan_danovskis 8220 flappybprob play flappy bird 1 800 273 8255 national suicide prevention lifeline rt save live 8221 r 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: omg gt throw beer bottle street yell drink homeless people stop harass trannies game6 torturebaseball
# Actual: 2
# Predicted: 0
# ---
# Tweet: look like dyke ur pic lol
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt imalagirl pillow talk yo hoe hat nigga fuck around loose ya hoe like 128175
# Actual: 0
# Predicted: 2
# ---
# Tweet: jennifer lawrence s nudes sooooo trash im still smashin though doubt
# Actual: 0
# Predicted: 2
# ---
# Tweet: can t stand sob ass bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: try non contact hockey dont call anyone else pussy
# Actual: 2
# Predicted: 1
# ---
# Tweet: altosteel115 http t co tm28mh5xg2 woof woof sexy thug boy scally
# Actual: 2
# Predicted: 1
# ---
# Tweet: shanafin34 gotta love tanner country hoe amp all haha
# Actual: 2
# Predicted: 0
# ---
# Tweet: shawnieceqb remember time hilfiger wus see polo until say aint wan niggers wear ish
# Actual: 2
# Predicted: 1
# ---
# Tweet: dude chicago w fuzzy mustache bang johnny love whack memoriesofidots
# Actual: 1
# Predicted: 2
# ---
# Tweet: limitlessmudi yodeddyugly y all trash
# Actual: 2
# Predicted: 1
# ---
# Tweet: vibing ask see aux cord know bout play trash 128530
# Actual: 1
# Predicted: 2
# ---
# Tweet: stanleystinks shame you self hat kike jews g d s choose people
# Actual: 0
# Predicted: 1
# ---
# Tweet: american culture stick side toilet graffiti writers europe create better art without lowlife trash sex joke
# Actual: 1
# Predicted: 0
# ---
# Tweet: rt murderhigashi cannot worry bout bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt lizeth0714 nc s weather seriously fucken retard gonna 40 something today almost 80 saturday
# Actual: 2
# Predicted: 1
# ---
# Tweet: norahodonnell dish texas trash talk pts racist jdickerson maybe gbush apologize sin hide
# Actual: 2
# Predicted: 1
# ---
# Tweet: djfeds make nigga e r bad charger phone rip text ipod ghetto
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt youngmiddleeric y all niggas ain t killas y all niggaz hoe
# Actual: 2
# Predicted: 0
# ---
# Tweet: jakiekoelewijn nigga who s bitch fuck cracker get gay ass mention
# Actual: 0
# Predicted: 2
# ---
# Tweet: hate black people try white bad nigger
# Actual: 0
# Predicted: 2
# ---
# Tweet: xtruthseekerx_ blaxican
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt brianndominguez green yellow lil wayne 128155 128154 128175 128175 128175 128175
# Actual: 1
# Predicted: 2
# ---
# Tweet: watch single episode lhhny however watch reunion coon shit mean level ratcheticity
# Actual: 1
# Predicted: 2
# ---
# Tweet: tell little bitch ass nigga do look like eat gun charge slap hoe ass lawyer
# Actual: 2
# Predicted: 0
# ---
# Tweet: the_gambit ha ain t welcome washington state nashville serpas straight trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: mama joyce wed grumpy ass bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: bbl gonna go sob gay bird baby
# Actual: 2
# Predicted: 1
# ---
# Tweet: triple6em96 hunglikerobby_ bitch watch fuck mouth dirty whore swear god that s thin line
# Actual: 0
# Predicted: 2
# ---
# Tweet: blanket nip would harder search anne frank
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt sweetiepaii rt listen band 128522 a7x ptv sws atl bvb adtr bmth ymas fob aa blink 182 tdg ss fir mcr follow amp everyon 8230
# Actual: 1
# Predicted: 2
# ---
# Tweet: rt whitepeopletalk 8220 kobe 8221 shoot piece paper trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: gossipcop coon n coon wanna b get have except time jail
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt cuhcuhcraig kawhi leonard smh rt 8220 idntwearcondoms wow really gonna leak ou nvm rt msjoseline ion need fuc nig http 8230
# Actual: 0
# Predicted: 2
# ---
# Tweet: girl know niggah trynna fuck
# Actual: 2
# Predicted: 0
# ---
# Tweet: kenzieblake2015 pretty easy actually cashier right eat animal crackers lolol
# Actual: 1
# Predicted: 2
# ---
# Tweet: one anglo saxon protestant right alive us none all foreign filth
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt now_thats_fresh every seth mcfarlene cartoon trash yall love low iq comedy
# Actual: 1
# Predicted: 2
# ---
# Tweet: iowahawkblog also recommend 6pack shiner bock 12 hours brisket duty the pit feed oak coal 128521
# Actual: 1
# Predicted: 2
# ---
# Tweet: da iamcolinquinn gonna reboot da jeffersons dis time gonna weezy marry pre op trannies
# Actual: 2
# Predicted: 0
# ---
# Tweet: porch monkey 4 life
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt chughes717 tyzebruh trash can always demand new music gawd tyga
# Actual: 1
# Predicted: 2
# ---
# Tweet: 128514 128514 128514 rt kwagiheath 1st 48 charlotte goon niccas gon fkkk around burn bank america stadium down 128293
# Actual: 0
# Predicted: 2
# ---
# Tweet: state gook
# Actual: 0
# Predicted: 1
# ---
# Tweet: sho_time_ mitchvorce chill ur pussy gay af
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt honey_gotbunns 1stblocjeremiah lmfaoo never dolo dont get niggas amp old hoe fuck 128074 128514 128514 128514
# Actual: 0
# Predicted: 2
# ---
# Tweet: ant_dgk buckm00se chainskibum would faggot survive tj
# Actual: 2
# Predicted: 0
# ---
# Tweet: gundeathjournal ackdoc nra lax gun laws ur retard there s murder bcuz one defend themselves crook gun
# Actual: 1
# Predicted: 2
# ---
# Tweet: therealgeorgez pussy without gun bitch spic daddy even respect sperm drop moms stink pussy
# Actual: 0
# Predicted: 2
# ---
# Tweet: after bo1 rt thegodwriter_ idoclyfe bruh lol retire mw2 everything trash afterwards
# Actual: 1
# Predicted: 2
# ---
# Tweet: yost portsmouth this biggest white trash county nation yostknowsmost idowntown
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt sblmnl_crmnl woods_lamar shut nigger ass lamar
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt maniac3x buckm00se rather rancho live ghetto ass urban areas niggers nigger impersonators adopt ni 8230
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt crittamo get tire ol hope break bitch job wanna twerk smoke swishers
# Actual: 2
# Predicted: 0
# ---
# Tweet: rt otbva mook gon wi 3 0 battle bad
# Actual: 1
# Predicted: 2
# ---
# Tweet: 8220 simplyhype kobebryant shut fuck up fuck trash nigga work another ring 8221 http t co 6rlenkr7ee
# Actual: 0
# Predicted: 2
# ---
# Tweet: corybooker run around town deliver food people take trash perfect boyfriend
# Actual: 1
# Predicted: 2
# ---
# Tweet: imtoblame fatherless wallet carry ass video game play ass negro breh filth way afford date twitterhoney
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt nostradamnisuck mary juicy clam always good go little touch boat man begin flow hallmarknostracollecti 8230
# Actual: 2
# Predicted: 1
# ---
# Tweet: can t disrespect ass bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: know nigga rapist y all hoe dumb 8220 daniellathepimp melt http t co rrrozn5bdy 8221
# Actual: 0
# Predicted: 2
# ---
# Tweet: always listen ghetto ass rap get ready football game
# Actual: 2
# Predicted: 0
# ---
# Tweet: thick bitch gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt
# Actual: 2
# Predicted: 1
# ---
# Tweet: trash tho rt ome23y edgewood basketball court now
# Actual: 2
# Predicted: 1
# ---
# Tweet: team_darrion night jigaboo http t co vxkcg4ygxf
# Actual: 1
# Predicted: 2
# ---
# Tweet: tracieeeeee wha me wait showtime bring back queer folk
# Actual: 1
# Predicted: 2
# ---
# Tweet: even though lil wayne s music turn trash ceilings human always favorites
# Actual: 1
# Predicted: 2
# ---
# Tweet: full moon out crazyassholes full force talk muzzies liberals 8252 65039 mood oblige
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt salon trash talk athlete vs violent congressman who s real thug here http t co dfndcqwdax via joanwalsh
# Actual: 2
# Predicted: 1
# ---
# Tweet: lmao rt ipostbadtweets lowkey peyton man trash
# Actual: 1
# Predicted: 2
# ---
# Tweet: oriental rugs cause flyer dive
# Actual: 1
# Predicted: 2
# ---
# Tweet: 128530 nerve work cos monkey 128529 128545
# Actual: 1
# Predicted: 2
# ---
# Tweet: s o flow well varsity soccer tomorrow yall play ironwood kick asses pretty sure fag play samjalexander
# Actual: 2
# Predicted: 1
# ---
# Tweet: school ghetto fuck http t co qrhwqtueu1
# Actual: 2
# Predicted: 0
# ---
# Tweet: gonewithkalijah watch 1st season bc want see diff side elijah see thristy hoe use walgreen s hair dye
# Actual: 2
# Predicted: 1
# ---
# Tweet: kieffer_jason let say clearly since retard ass understand
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt greyyygoose marsvalo cheesus85 shut bitch lol
# Actual: 2
# Predicted: 0
# ---
# Tweet: i m gonna piss dimple soni99a_ stop waste prayers trash team lol
# Actual: 2
# Predicted: 1
# ---
# Tweet: niggah pharrell whatever niggah name deserve shit white ass gay song
# Actual: 0
# Predicted: 2
# ---
# Tweet: rt dezdlt i play soccer cheat girls wear khaki colour cargos haircut http t co a1sdhby8xt
# Actual: 2
# Predicted: 1
# ---
# Tweet: degenerateartist sniff whiffy ball involuntary cuz fairy walk downtown hairy climatechange scary sense hillbilly sneeze gt
# Actual: 1
# Predicted: 2
# ---
# Tweet: stevestockmantx hes friggin idiot say anything redneck teabagger constituants buy it love stupid people
# Actual: 0
# Predicted: 2
# ---
# Tweet: dey give da wrong nicca money
# Actual: 2
# Predicted: 1
# ---
# Tweet: rt funnypicsdepot bitch mall shape like mr incredible http t co l8cuvnznwm
# Actual: 2
# Predicted: 0
# ---
# Tweet: unfollowed say cry watch dawn ape lmaooooooo
# Actual: 1
# Predicted: 2
# ---
# Tweet: can t never bitch nigga thats get treat like bitch
# Actual: 2
# Predicted: 0
# ---
# Tweet: grizzboadams wyattnuckels haha ight nig calm yoself
# Actual: 0
# Predicted: 2
# ---
# Tweet: fat trel niggah 128076
# Actual: 2
# Predicted: 0
# ---

# %%
# Final model comparison bar chart — using actual evaluation metrics
import numpy as np

models = ['SimpleRNN', 'LSTM', 'LSTM + Word2Vec']

macro_p = [macro_precision_model1, macro_precision_model2, macro_precision_model3]
macro_r = [macro_recall_model1, macro_recall_model2, macro_recall_model3]
macro_f1 = [macro_f1_model1, macro_f1_model2, macro_f1_model3]
accuracies = [accuracy_score(y_test_encoded, y_pred_classes_model1), accuracy_score(y_test_encoded, y_pred_classes_model2), accuracy_score(y_test_encoded, y_pred_classes_model3)]

x = np.arange(len(models))
width = 0.2

plt.figure(figsize=(10,6))
plt.bar(x - width*1.5, macro_p, width, label='Macro Precision', color='#ff6b6b')
plt.bar(x - width/2, macro_r, width, label='Macro Recall', color='#ffd93d')
plt.bar(x + width/2, macro_f1, width, label='Macro F1', color='#6bcb77')
plt.bar(x + width*1.5, accuracies, width, label='Accuracy', color='#4d96ff')

plt.xticks(x, models, fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.title('Model Performance Comparison', fontsize=14, fontweight='bold')
plt.ylim(0,1.0)
plt.legend(loc='lower right')
plt.tight_layout()
os.makedirs('./outputs/figures/comparisons', exist_ok=True)
plt.savefig('./outputs/figures/comparisons/model_comparison.png', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ## UI using gradio (optional)
#
# - Wrap preprocessing + tokenization + model inference into a `predict_tweet` helper.
# - Build a minimal Gradio UI for interactive testing.
#
# - **_This makes it easy to try edge cases and demonstrate the classifier._**

# %%
import gradio as gr

def predict_tweet(text): 
    """Predict the class label for a user-provided tweet string.

    Uses the same preprocessing, tokenizer, and padding settings as training,
    then runs the trained model and decodes the predicted label.

    Args:
        text (str): Raw tweet text.

    Returns:
        str: Predicted label (one of the original dataset label strings).
    """
    cleaned = text_cleaning_pipeline(text)

    seq = tokenizer.texts_to_sequences([cleaned])

    padded = pad_sequences(seq, maxlen=max_length)
    pred = model2.predict(padded)

    label = label_encoder.inverse_transform([pred.argmax() ])[0]
    return label

gr.Interface(
    fn=predict_tweet,
    inputs="text",
    outputs="text"
).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
